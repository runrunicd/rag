# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import os
import networkx as nx
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS
import tensorflow as tf
from IPython.display import YouTubeVideo
plt.style.use('ggplot')
# Out:
# 2024-03-21 18:07:56.399135: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
DATA_PATH = "/Users/runzhou/Desktop/youtube/data/yt8m/video/"
# Inspect data directory
print(os.listdir(DATA_PATH))

# Explore video-level data
video_lvl_data_path = DATA_PATH + "train0274.tfrecord"
raw_dataset = tf.data.TFRecordDataset(video_lvl_data_path)


vid_ids = []
labels = []
rgb = []
audio = []

for example in tf.compat.v1.python_io.tf_record_iterator(video_lvl_data_path):
    seq_example = tf.train.Example.FromString(example)
    vid_ids.append(seq_example.features.feature['id'].bytes_list.value[0].decode(encoding='UTF-8'))
    labels.append(seq_example.features.feature['labels'].int64_list.value)
    rgb.append(seq_example.features.feature['mean_rgb'].float_list.value)
    audio.append(seq_example.features.feature['mean_audio'].float_list.value)

print('Number of videos in this tfrecord: ',len(vid_ids))
print ('Number of labels in this tfrecord: ', len (labels))
print('Number of mean RGB in this tfrecord: ', len(rgb))
print('Number of mean audio in this tfrecord: ', len(audio))
print('Picking a youtube video id:', vid_ids[1])
# Out:
# ['2_video_train_download_plan.json', 'train0434.tfrecord', 'train0274.tfrecord', 'train0208.tfrecord', 'train0580.tfrecord', 'train2161.tfrecord']
# Number of videos in this tfrecord:  1045
# Number of labels in this tfrecord:  1045
# Number of mean RGB in this tfrecord:  1045
# Number of mean audio in this tfrecord:  1045
# Picking a youtube video id: zseA

# %%
DATA_PATH = "/Users/runzhou/Desktop/youtube/data/yt8m/frame/"
# Inspect frame-level data directory
print(os.listdir(DATA_PATH))

import tensorflow as tf

# Explore frame-level data
frame_lvl_data_path = DATA_PATH + "train0274.tfrecord"
raw_dataset = tf.data.TFRecordDataset(frame_lvl_data_path)

vid_ids = []
labels = []
rgb = []
audio = []

for example in tf.compat.v1.python_io.tf_record_iterator(frame_lvl_data_path):
    seq_example = tf.train.SequenceExample.FromString(example)
    vid_ids.append(seq_example.context.feature['id'].bytes_list.value[0].decode(encoding='UTF-8'))
    labels.append(seq_example.context.feature['labels'].int64_list.value)

    # Decode RGB features
    rgb_encoded = seq_example.feature_lists.feature_list['rgb'].feature[0].bytes_list.value[0]
    rgb_decoded = tf.io.decode_raw(rgb_encoded, tf.float32)
    rgb.append(rgb_decoded.numpy().tolist())

    # Decode audio features
    audio_encoded = seq_example.feature_lists.feature_list['audio'].feature[0].bytes_list.value[0]
    audio_decoded = tf.io.decode_raw(audio_encoded, tf.float32)
    audio.append(audio_decoded.numpy().tolist())

print('Number of videos in this tfrecord: ',len(vid_ids))
print ('Number of labels in this tfrecord: ', len (labels))
print('Number of mean RGB in this tfrecord: ', len(rgb))
print('Number of mean audio in this tfrecord: ', len(audio))
print('Picking a youtube video id:', vid_ids[1])
# Out:
# ['2_frame_train_download_plan.json', 'train0274.tfrecord', 'train0580.tfrecord', 'train2161.tfrecord']
# Number of videos in this tfrecord:  1045
# Number of labels in this tfrecord:  1045
# Number of mean RGB in this tfrecord:  1045
# Number of mean audio in this tfrecord:  1045
# Picking a youtube video id: WjeA

# %%
DATA_PATH = "/Users/runzhou/Desktop/youtube/data/yt8m/segment/"

# Inspect segment-level data directory
print(os.listdir(DATA_PATH))

# Explore segment-level data
segment_lvl_data_path = DATA_PATH + "validate3489.tfrecord"
raw_dataset = tf.data.TFRecordDataset(segment_lvl_data_path)

vid_ids = []
labels = []
rgb = []
audio = []
segment_start_times = []
segment_end_times = []
segment_scores = []
segment_labels = []


for example in tf.compat.v1.python_io.tf_record_iterator(segment_lvl_data_path):
    # Context features
    example_example = tf.train.Example.FromString(example)
    
    vid_ids.append(example_example.features.feature['id'].bytes_list.value[0].decode(encoding='UTF-8'))
    labels.append(example_example.features.feature['labels'].int64_list.value)

    # Segment labels & scores
    segment_start_times.append(example_example.features.feature['segment_start_times'].int64_list.value)
    segment_end_times.append(example_example.features.feature['segment_end_times'].int64_list.value)
    segment_labels.append(example_example.features.feature['segment_labels'].int64_list.value)

    # Frame features
    seq_example = tf.train.SequenceExample.FromString(example)

    # Decode RGB features
    rgb_encoded = seq_example.feature_lists.feature_list['rgb'].feature[0].bytes_list.value[0]
    rgb_decoded = tf.io.decode_raw(rgb_encoded, tf.uint8)
    rgb.append(rgb_decoded.numpy().tolist())

    # Decode audio features
    audio_encoded = seq_example.feature_lists.feature_list['audio'].feature[0].bytes_list.value[0]
    audio_decoded = tf.io.decode_raw(audio_encoded, tf.uint8)
    audio.append(audio_decoded.numpy().tolist())


print('Number of videos in this tfrecord: ',len(vid_ids))
print ('Number of labels in this tfrecord: ', len (labels))
print('Number of mean RGB in this tfrecord: ', len(rgb))
print('Number of mean audio in this tfrecord: ', len(audio))
print('Picking a youtube video id:', vid_ids[1])
# Out:
# ['validate3489.tfrecord', '3_frame_validate_download_plan.json']
# Number of videos in this tfrecord:  8
# Number of labels in this tfrecord:  8
# Number of mean RGB in this tfrecord:  8
# Number of mean audio in this tfrecord:  8
# Picking a youtube video id: Xd4r

# %%
#rgb: 8 x 1024
#audio: 8 x 128
len(audio[0])
# Out:
# 128

# %%
# Translate video ID to Youtube URL
import requests

def translate_video_id(encoded_id):
    # Construct the URL to retrieve the mapping
    url = f"http://data.yt8m.org/2/j/i/{encoded_id[:2]}/{encoded_id}.js"
    response = requests.get(url)

    # Check if the response is successful and has the expected format
    if response.status_code == 200 and 'i("' in response.text:
        # Extract the standard YouTube video ID from the response
        video_id = response.text.split('"')[3]
        return video_id
    else:
        # Log an error or handle it as appropriate
        print(f"Error retrieving video ID for {encoded_id}: {response.text}")
        return '200'

youtube_urls = []
for encoded_id in vid_ids:
    video_id = translate_video_id(encoded_id)
    if video_id:
        youtube_url = f"https://www.youtube.com/watch?v={video_id}"
        youtube_urls.append(youtube_url)

# Print or use the YouTube URLs
for url in youtube_urls:
    print(url)
# Out:
# Error retrieving video ID for Xw4r: <?xml version='1.0' encoding='UTF-8'?><Error><Code>AccessDenied</Code><Message>Access denied.</Message></Error>
# Error retrieving video ID for En4r: <?xml version='1.0' encoding='UTF-8'?><Error><Code>AccessDenied</Code><Message>Access denied.</Message></Error>
# https://www.youtube.com/watch?v=KYVAv4gq00k
# https://www.youtube.com/watch?v=Ph-dQZnHChc
# https://www.youtube.com/watch?v=jGve-X-fJug
# https://www.youtube.com/watch?v=GnbzWaaIGRY
# https://www.youtube.com/watch?v=200
# https://www.youtube.com/watch?v=200
# https://www.youtube.com/watch?v=DTQpR-AqKnM
# https://www.youtube.com/watch?v=tTfptynuWdA

# %%
DATA_PATH = "/Users/runzhou/Desktop/youtube/data/"
# Read in vocabulary for human-rated mapping of numeric label to text label for the video
vocab = pd.read_csv(DATA_PATH + 'vocabulary.csv')

# Create a pandas dataframe to store the segment-rated frame-level contextual data and embeddings
df = pd.DataFrame()

for i, encoded_id in enumerate(vid_ids):
    video_id = translate_video_id(encoded_id)
    if video_id:
        youtube_url = f"https://www.youtube.com/watch?v={video_id}"
    
    text_labels = [vocab[vocab['Index'] == label]['Name'].values[0] for label in labels[i]]
    wiki_descriptions = [vocab[vocab['Index'] == label]['WikiDescription'].values[0] for label in labels[i]]
    text_segment_labels = [vocab[vocab['Index'] == label]['Name'].values[0] for label in segment_labels[i]]
    df = pd.concat([df, pd.DataFrame([{'labels': labels[i],
                    'text_labels': text_labels,
                    'url': youtube_url,
                    'WikiDescription': wiki_descriptions,
                    'text_segment_labels': text_segment_labels,
                    'segment_labels': segment_labels[i],
                    'segment_start_times': segment_start_times[i],
                    'segment_end_times': segment_end_times[i],
                    'mean_rgb': rgb[i],
                    'mean_audio': audio[i]}])],
                    ignore_index=True)

# Display the DataFrame
print(df)
# Out:
# Error retrieving video ID for Xw4r: <?xml version='1.0' encoding='UTF-8'?><Error><Code>AccessDenied</Code><Message>Access denied.</Message></Error>
# Error retrieving video ID for En4r: <?xml version='1.0' encoding='UTF-8'?><Error><Code>AccessDenied</Code><Message>Access denied.</Message></Error>
#                    labels                                   text_labels  \
# 0       [2, 76, 281, 446]             [Vehicle, Boat, Motorboat, Yacht]
# 1                   [191]                                       [Hotel]
# 2  [11, 1366, 1684, 1872]    [Food, Grocery store, Supermarket, Retail]
# 3        [2, 7, 116, 235]    [Vehicle, Car, Sport utility vehicle, nan]
# 4             [461, 1325]                    [Printer (computing), Ink]
# 5                   [607]                                  [Board game]
# 6       [0, 1, 234, 1303]  [Game, Video game, Super Smash Bros., Yoshi]
# 7                [17, 19]                          [Motorsport, Racing]
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=KYVAv4gq00k
# 1  https://www.youtube.com/watch?v=Ph-dQZnHChc
# 2  https://www.youtube.com/watch?v=jGve-X-fJug
# 3  https://www.youtube.com/watch?v=GnbzWaaIGRY
# 4          https://www.youtube.com/watch?v=200
# 5          https://www.youtube.com/watch?v=200
# 6  https://www.youtube.com/watch?v=DTQpR-AqKnM
# 7  https://www.youtube.com/watch?v=tTfptynuWdA
#
#                                      WikiDescription  \
# 0  [A vehicle is a mobile machine that transports...
# 1  [A hotel is an establishment that provides pai...
# 2  [Food is any substance consumed to provide nut...
# 3  [A vehicle is a mobile machine that transports...
# 4  [In computing, a printer is a peripheral which...
# 5  [A board game is a tabletop game that involves...
# 6  [A game is structured form of play, usually un...
# 7  [Motorsport or motorsports is a global term us...
#
#                                  text_segment_labels  \
# 0  [Luxury yacht, Luxury yacht, Luxury yacht, Lux...
# 1                              [Hotel, Hotel, Hotel]
# 2  [Grocery store, Grocery store, Grocery store, ...
# 3  [Sport utility vehicle, Sport utility vehicle,...
# 4                          [Ink, Ink, Ink, Ink, Ink]
# 5  [Board game, Board game, Board game, Board gam...
# 6                [Yoshi, Yoshi, Yoshi, Yoshi, Yoshi]
# 7      [Running, Running, Running, Running, Running]
#
#                                       segment_labels  \
# 0                     [1314, 1314, 1314, 1314, 1314]
# 1                                    [191, 191, 191]
# 2                     [1366, 1366, 1366, 1366, 1366]
# 3  [116, 116, 116, 235, 116, 235, 235, 116, 235, ...
# 4                     [1325, 1325, 1325, 1325, 1325]
# 5                          [607, 607, 607, 607, 607]
# 6                     [1303, 1303, 1303, 1303, 1303]
# 7                          [210, 210, 210, 210, 210]
#
#                                 segment_start_times  \
# 0                          [50, 165, 230, 115, 210]
# 1                                   [200, 255, 230]
# 2                           [85, 220, 230, 125, 45]
# 3  [265, 220, 65, 180, 105, 230, 105, 85, 135, 165]
# 4                             [50, 45, 85, 35, 110]
# 5                           [95, 215, 140, 60, 145]
# 6                          [185, 45, 190, 105, 195]
# 7                              [40, 65, 80, 30, 55]
#
#                                   segment_end_times  \
# 0                          [55, 170, 235, 120, 215]
# 1                                   [205, 260, 235]
# 2                           [90, 225, 235, 130, 50]
# 3  [270, 225, 70, 185, 110, 235, 110, 90, 140, 170]
# 4                             [55, 50, 90, 40, 115]
# 5                          [100, 220, 145, 65, 150]
# 6                          [190, 50, 195, 110, 200]
# 7                              [45, 70, 85, 35, 60]
#
#                                             mean_rgb  \
# 0  [0, 75, 148, 37, 0, 0, 74, 28, 194, 118, 230, ...
# 1  [89, 195, 86, 213, 96, 100, 151, 183, 103, 151...
# 2  [0, 72, 173, 30, 0, 0, 40, 33, 199, 132, 199, ...
# 3  [95, 203, 71, 171, 124, 165, 110, 172, 123, 17...
# 4  [86, 33, 92, 131, 206, 63, 92, 178, 43, 139, 5...
# 5  [116, 161, 174, 145, 99, 88, 64, 117, 147, 104...
# 6  [181, 16, 82, 162, 190, 255, 88, 28, 202, 213,...
# 7  [120, 193, 70, 224, 104, 170, 113, 125, 118, 1...
#
#                                           mean_audio
# 0  [175, 43, 116, 109, 154, 93, 75, 198, 172, 171...
# 1  [163, 55, 116, 98, 91, 183, 151, 157, 177, 117...
# 2  [175, 47, 132, 85, 169, 168, 156, 167, 157, 13...
# 3  [157, 37, 131, 92, 127, 93, 194, 217, 140, 103...
# 4  [133, 86, 84, 137, 155, 55, 95, 83, 153, 123, ...
# 5  [105, 70, 109, 126, 116, 29, 122, 114, 181, 18...
# 6  [156, 218, 194, 148, 121, 42, 8, 73, 68, 35, 9...
# 7  [65, 70, 167, 165, 166, 107, 173, 41, 113, 238...

# %%
df.head(5)
# Out:
#                    labels                                 text_labels  \
# 0       [2, 76, 281, 446]           [Vehicle, Boat, Motorboat, Yacht]
# 1                   [191]                                     [Hotel]
# 2  [11, 1366, 1684, 1872]  [Food, Grocery store, Supermarket, Retail]
# 3        [2, 7, 116, 235]  [Vehicle, Car, Sport utility vehicle, nan]
# 4             [461, 1325]                  [Printer (computing), Ink]
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=KYVAv4gq00k
# 1  https://www.youtube.com/watch?v=Ph-dQZnHChc
# 2  https://www.youtube.com/watch?v=jGve-X-fJug
# 3  https://www.youtube.com/watch?v=GnbzWaaIGRY
# 4          https://www.youtube.com/watch?v=200
#
#                                      WikiDescription  \
# 0  [A vehicle is a mobile machine that transports...
# 1  [A hotel is an establishment that provides pai...
# 2  [Food is any substance consumed to provide nut...
# 3  [A vehicle is a mobile machine that transports...
# 4  [In computing, a printer is a peripheral which...
#
#                                  text_segment_labels  \
# 0  [Luxury yacht, Luxury yacht, Luxury yacht, Lux...
# 1                              [Hotel, Hotel, Hotel]
# 2  [Grocery store, Grocery store, Grocery store, ...
# 3  [Sport utility vehicle, Sport utility vehicle,...
# 4                          [Ink, Ink, Ink, Ink, Ink]
#
#                                       segment_labels  \
# 0                     [1314, 1314, 1314, 1314, 1314]
# 1                                    [191, 191, 191]
# 2                     [1366, 1366, 1366, 1366, 1366]
# 3  [116, 116, 116, 235, 116, 235, 235, 116, 235, ...
# 4                     [1325, 1325, 1325, 1325, 1325]
#
#                                 segment_start_times  \
# 0                          [50, 165, 230, 115, 210]
# 1                                   [200, 255, 230]
# 2                           [85, 220, 230, 125, 45]
# 3  [265, 220, 65, 180, 105, 230, 105, 85, 135, 165]
# 4                             [50, 45, 85, 35, 110]
#
#                                   segment_end_times  \
# 0                          [55, 170, 235, 120, 215]
# 1                                   [205, 260, 235]
# 2                           [90, 225, 235, 130, 50]
# 3  [270, 225, 70, 185, 110, 235, 110, 90, 140, 170]
# 4                             [55, 50, 90, 40, 115]
#
#                                             mean_rgb  \
# 0  [0, 75, 148, 37, 0, 0, 74, 28, 194, 118, 230, ...
# 1  [89, 195, 86, 213, 96, 100, 151, 183, 103, 151...
# 2  [0, 72, 173, 30, 0, 0, 40, 33, 199, 132, 199, ...
# 3  [95, 203, 71, 171, 124, 165, 110, 172, 123, 17...
# 4  [86, 33, 92, 131, 206, 63, 92, 178, 43, 139, 5...
#
#                                           mean_audio
# 0  [175, 43, 116, 109, 154, 93, 75, 198, 172, 171...
# 1  [163, 55, 116, 98, 91, 183, 151, 157, 177, 117...
# 2  [175, 47, 132, 85, 169, 168, 156, 167, 157, 13...
# 3  [157, 37, 131, 92, 127, 93, 194, 217, 140, 103...
# 4  [133, 86, 84, 137, 155, 55, 95, 83, 153, 123, ...

# %% [markdown]
# #### Build a generic RAG system

# %%
#!sudo apt-get install build-essential libssl-dev python3-dev
#!python -m pip install --upgrade pip setuptools wheel
#!python -m pip install grpcio

#!python -m pip install chromadb

#!python --version

# %%
df.head(10)
# Out:
#                    labels                                   text_labels  \
# 0       [2, 76, 281, 446]             [Vehicle, Boat, Motorboat, Yacht]
# 1                   [191]                                       [Hotel]
# 2  [11, 1366, 1684, 1872]    [Food, Grocery store, Supermarket, Retail]
# 3        [2, 7, 116, 235]    [Vehicle, Car, Sport utility vehicle, nan]
# 4             [461, 1325]                    [Printer (computing), Ink]
# 5                   [607]                                  [Board game]
# 6       [0, 1, 234, 1303]  [Game, Video game, Super Smash Bros., Yoshi]
# 7                [17, 19]                          [Motorsport, Racing]
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=KYVAv4gq00k
# 1  https://www.youtube.com/watch?v=Ph-dQZnHChc
# 2  https://www.youtube.com/watch?v=jGve-X-fJug
# 3  https://www.youtube.com/watch?v=GnbzWaaIGRY
# 4          https://www.youtube.com/watch?v=200
# 5          https://www.youtube.com/watch?v=200
# 6  https://www.youtube.com/watch?v=DTQpR-AqKnM
# 7  https://www.youtube.com/watch?v=tTfptynuWdA
#
#                                      WikiDescription  \
# 0  [A vehicle is a mobile machine that transports...
# 1  [A hotel is an establishment that provides pai...
# 2  [Food is any substance consumed to provide nut...
# 3  [A vehicle is a mobile machine that transports...
# 4  [In computing, a printer is a peripheral which...
# 5  [A board game is a tabletop game that involves...
# 6  [A game is structured form of play, usually un...
# 7  [Motorsport or motorsports is a global term us...
#
#                                  text_segment_labels  \
# 0  [Luxury yacht, Luxury yacht, Luxury yacht, Lux...
# 1                              [Hotel, Hotel, Hotel]
# 2  [Grocery store, Grocery store, Grocery store, ...
# 3  [Sport utility vehicle, Sport utility vehicle,...
# 4                          [Ink, Ink, Ink, Ink, Ink]
# 5  [Board game, Board game, Board game, Board gam...
# 6                [Yoshi, Yoshi, Yoshi, Yoshi, Yoshi]
# 7      [Running, Running, Running, Running, Running]
#
#                                       segment_labels  \
# 0                     [1314, 1314, 1314, 1314, 1314]
# 1                                    [191, 191, 191]
# 2                     [1366, 1366, 1366, 1366, 1366]
# 3  [116, 116, 116, 235, 116, 235, 235, 116, 235, ...
# 4                     [1325, 1325, 1325, 1325, 1325]
# 5                          [607, 607, 607, 607, 607]
# 6                     [1303, 1303, 1303, 1303, 1303]
# 7                          [210, 210, 210, 210, 210]
#
#                                 segment_start_times  \
# 0                          [50, 165, 230, 115, 210]
# 1                                   [200, 255, 230]
# 2                           [85, 220, 230, 125, 45]
# 3  [265, 220, 65, 180, 105, 230, 105, 85, 135, 165]
# 4                             [50, 45, 85, 35, 110]
# 5                           [95, 215, 140, 60, 145]
# 6                          [185, 45, 190, 105, 195]
# 7                              [40, 65, 80, 30, 55]
#
#                                   segment_end_times  \
# 0                          [55, 170, 235, 120, 215]
# 1                                   [205, 260, 235]
# 2                           [90, 225, 235, 130, 50]
# 3  [270, 225, 70, 185, 110, 235, 110, 90, 140, 170]
# 4                             [55, 50, 90, 40, 115]
# 5                          [100, 220, 145, 65, 150]
# 6                          [190, 50, 195, 110, 200]
# 7                              [45, 70, 85, 35, 60]
#
#                                             mean_rgb  \
# 0  [0, 75, 148, 37, 0, 0, 74, 28, 194, 118, 230, ...
# 1  [89, 195, 86, 213, 96, 100, 151, 183, 103, 151...
# 2  [0, 72, 173, 30, 0, 0, 40, 33, 199, 132, 199, ...
# 3  [95, 203, 71, 171, 124, 165, 110, 172, 123, 17...
# 4  [86, 33, 92, 131, 206, 63, 92, 178, 43, 139, 5...
# 5  [116, 161, 174, 145, 99, 88, 64, 117, 147, 104...
# 6  [181, 16, 82, 162, 190, 255, 88, 28, 202, 213,...
# 7  [120, 193, 70, 224, 104, 170, 113, 125, 118, 1...
#
#                                           mean_audio
# 0  [175, 43, 116, 109, 154, 93, 75, 198, 172, 171...
# 1  [163, 55, 116, 98, 91, 183, 151, 157, 177, 117...
# 2  [175, 47, 132, 85, 169, 168, 156, 167, 157, 13...
# 3  [157, 37, 131, 92, 127, 93, 194, 217, 140, 103...
# 4  [133, 86, 84, 137, 155, 55, 95, 83, 153, 123, ...
# 5  [105, 70, 109, 126, 116, 29, 122, 114, 181, 18...
# 6  [156, 218, 194, 148, 121, 42, 8, 73, 68, 35, 9...
# 7  [65, 70, 167, 165, 166, 107, 173, 41, 113, 238...

# %%
import chromadb

# Initialize the ChromaDB client
chroma_client = chromadb.Client()

#Create a collections to store your embeddings, documents, and any additional metadata. 
collection = chroma_client.get_or_create_collection(name='rgb_collection')

# Store embeddings in ChromaDB
for i, row in df.iterrows():
    # Create a unique ID for each embedding
    id = f'{i}'

    # Get info of each row
    metadatas_dict = {
    #'labels': row['labels'],
    #'text_labels': row['text_labels'],
    #'segment_labels': row['segment_labels'],
    #'text_segment_labels': row['text_segment_labels'],
    #'segment_start_times': row['segment_start_times'],
    #'segment_end_times': row['segment_end_times'],
    'url': row['url'],
    'wiki': row['WikiDescription'][0]}

    # Store the embedding in ChromaDB
    collection.add(
        embeddings=row['mean_rgb'],
        metadatas=metadatas_dict,
        ids=id
    )

print('Embeddings stored in ChromaDB successfully.')
# Out:
# Embeddings stored in ChromaDB successfully.

# %%
# get items from a collection
collection.peek()
# Out:
# {'ids': ['0', '1', '2', '3', '4', '5', '6', '7'],
#  'embeddings': [[0.0,
#    75.0,
#    148.0,
#    37.0,
#    0.0,
#    0.0,
#    74.0,
#    28.0,
#    194.0,
#    118.0,
#    230.0,
#    85.0,
#    58.0,
#    164.0,
#    155.0,
#    195.0,
#    70.0,
#    99.0,
#    63.0,
#    247.0,
#    106.0,
#    225.0,
#    163.0,
#    130.0,
#    110.0,
#    7.0,
#    239.0,
#    131.0,
#    51.0,
#    140.0,
#    128.0,
#    194.0,
#    78.0,
#    72.0,
#    115.0,
#    115.0,
#    112.0,
#    214.0,
#    123.0,
#    81.0,
#    109.0,
#    146.0,
#    102.0,
#    187.0,
#    155.0,
#    125.0,
#    159.0,
#    130.0,
#    164.0,
#    84.0,
#    165.0,
#    112.0,
#    106.0,
#    96.0,
#    93.0,
#    108.0,
#    121.0,
#    120.0,
#    88.0,
#    111.0,
#    103.0,
#    116.0,
#    208.0,
#    81.0,
#    131.0,
#    227.0,
#    135.0,
#    136.0,
#    123.0,
#    160.0,
#    157.0,
#    148.0,
#    102.0,
#    32.0,
#    5.0,
#    34.0,
#    167.0,
#    179.0,
#    145.0,
#    87.0,
#    227.0,
#    137.0,
#    68.0,
#    255.0,
#    36.0,
#    255.0,
#    142.0,
#    129.0,
#    108.0,
#    142.0,
#    104.0,
#    67.0,
#    87.0,
#    68.0,
#    237.0,
#    70.0,
#    89.0,
#    234.0,
#    225.0,
#    129.0,
#    102.0,
#    145.0,
#    92.0,
#    101.0,
#    130.0,
#    103.0,
#    183.0,
#    129.0,
#    91.0,
#    167.0,
#    145.0,
#    65.0,
#    155.0,
#    243.0,
#    117.0,
#    152.0,
#    8.0,
#    169.0,
#    236.0,
#    0.0,
#    144.0,
#    105.0,
#    151.0,
#    154.0,
#    157.0,
#    135.0,
#    149.0,
#    145.0,
#    193.0,
#    61.0,
#    166.0,
#    143.0,
#    85.0,
#    115.0,
#    130.0,
#    69.0,
#    74.0,
#    141.0,
#    57.0,
#    146.0,
#    200.0,
#    102.0,
#    140.0,
#    74.0,
#    69.0,
#    122.0,
#    156.0,
#    94.0,
#    213.0,
#    39.0,
#    177.0,
#    114.0,
#    86.0,
#    106.0,
#    199.0,
#    205.0,
#    212.0,
#    183.0,
#    26.0,
#    212.0,
#    102.0,
#    81.0,
#    133.0,
#    ...]],
#  'metadatas': [{'url': 'https://www.youtube.com/watch?v=KYVAv4gq00k',
#    'wiki': 'A vehicle is a mobile machine that transports people or cargo. Typical vehicles include wagons, bicycles, motor vehicles, railed vehicles, watercraft, aircraft and spacecraft. Land vehicles are classified broadly by what is used to apply steering and drive forces against the ground: wheeled, tracked, railed or skied. ISO 3833-1977 is the standard, also internationally used in legislation, for road vehicles types, terms and definitions.'},
#   {'url': 'https://www.youtube.com/watch?v=Ph-dQZnHChc',
#    'wiki': 'A hotel is an establishment that provides paid lodging on a short-term basis. Facilities provided may range from a modest-quality mattress in a small room to large suites with bigger, higher-quality beds, a dresser, a fridge and other kitchen facilities, upholstered chairs, a flatscreen television and en-suite bathrooms. Small, lower-priced hotels may offer only the most basic guest services and facilities. Larger, higher-priced hotels may provide additional guest facilities such as a swimming pool, business centre, childcare, conference and event facilities, tennis or basketball courts, gymnasium, restaurants, day spa and social function services. Hotel rooms are usually numbered to allow guests to identify their room. Some boutique, high-end hotels have custom decorated rooms. Some hotels offer meals as part of a room and board arrangement. In the United Kingdom, a hotel is required by law to serve food and drinks to all guests within certain stated hours. In Japan, capsule hotels provide a tiny room suitable only for sleeping and shared bathroom facilities. The precursor to the modern hotel was the inn of medieval Europe.'},
#   {'url': 'https://www.youtube.com/watch?v=jGve-X-fJug',
#    'wiki': "Food is any substance consumed to provide nutritional support for the body. It is usually of plant or animal origin, and contains essential nutrients, such as carbohydrates, fats, proteins, vitamins, or minerals. The substance is ingested by an organism and assimilated by the organism's cells to provide energy, maintain life, or stimulate growth. Historically, people secured food through two methods: hunting and gathering and agriculture. Today, the majority of the food energy required by the ever increasing population of the world is supplied by the food industry. Food safety and food security are monitored by agencies like the International Association for Food Protection, World Resources Institute, World Food Programme, Food and Agriculture Organization, and International Food Information Council. They address issues such as sustainability, biological diversity, climate change, nutritional economics, population growth, water supply, and access to food."},
#   {'url': 'https://www.youtube.com/watch?v=GnbzWaaIGRY',
#    'wiki': 'A vehicle is a mobile machine that transports people or cargo. Typical vehicles include wagons, bicycles, motor vehicles, railed vehicles, watercraft, aircraft and spacecraft. Land vehicles are classified broadly by what is used to apply steering and drive forces against the ground: wheeled, tracked, railed or skied. ISO 3833-1977 is the standard, also internationally used in legislation, for road vehicles types, terms and definitions.'},
#   {'url': 'https://www.youtube.com/watch?v=200',
#    'wiki': "In computing, a printer is a peripheral which makes a persistent human-readable representation of graphics or text on paper or similar physical media. The world's first computer printer was a 19th-century mechanically driven apparatus invented by Charles Babbage for his difference engine. The first commercial printers generally used mechanisms from electric typewriters and Teletype machines The demand for higher speed led to the development of new systems specifically for computer use. In the 1980s were daisy wheel systems similar to typewriters, line printers that produced similar output but at much higher speed, and dot matrix systems that could mix text and graphics but produced relatively low-quality output. The plotter was used for those requiring high quality line art like blueprints. The introduction of the low-cost laser printer in 1984 with the first HP LaserJet, and the addition of PostScript in next year's Apple LaserWriter, set off a revolution in printing known as desktop publishing. Laser printers using PostScript mixed text and graphics, like dot-matrix printers, but at quality levels formerly available only from commercial typesetting systems."},
#   {'url': 'https://www.youtube.com/watch?v=200',
#    'wiki': 'A board game is a tabletop game that involves counters or pieces moved or placed on a pre-marked surface or "board", according to a set of rules. Some games are based on pure strategy, but many contain an element of chance; and some are purely chance, with no element of skill. Games usually have a goal that a player aims to achieve. Early board games represented a battle between two armies, and most modern board games are still based on defeating opposing players in terms of counters, winning position, or accrual of points. There are many varieties of board games. Their representation of real-life situations can range from having no inherent theme, like checkers, to having a specific theme and narrative, like Cluedo. Rules can range from the very simple, like Tic-tac-toe, to those describing a game universe in great detail, like Dungeons & Dragons – although most of the latter are role-playing games where the board is secondary to the game, serving to help visualize the game scenario.'},
#   {'url': 'https://www.youtube.com/watch?v=DTQpR-AqKnM',
#    'wiki': 'A game is structured form of play, usually undertaken for enjoyment and sometimes used as an educational tool. Games are distinct from work, which is usually carried out for remuneration, and from art, which is more often an expression of aesthetic or ideological elements. However, the distinction is not clear-cut, and many games are also considered to be work or art. Key components of games are goals, rules, challenge, and interaction. Games generally involve mental or physical stimulation, and often both. Many games help develop practical skills, serve as a form of exercise, or otherwise perform an educational, simulational, or psychological role. Attested as early as 2600 BC, games are a universal part of human experience and present in all cultures. The Royal Game of Ur, Senet, and Mancala are some of the oldest known games.'},
#   {'url': 'https://www.youtube.com/watch?v=tTfptynuWdA',
#    'wiki': "Motorsport or motorsports is a global term used to encompass the group of competitive events which primarily involve the use of motorised vehicles, whether for racing or non-racing competition. The terminology can also be used to describe forms of competition of two-wheeled motorised vehicles under the banner of motorcycle racing, and includes off-road racing such as motocross. Four- wheeled motorsport competition is globally governed by the Fédération Internationale de l'Automobile; and the Fédération Internationale de Motocyclisme governs two-wheeled competition."}],
#  'documents': [None, None, None, None, None, None, None, None],
#  'uris': None,
#  'data': None}

# %%
# do nearest neighbor search to find similar embeddings or documents, supports filtering
collection.query(
    query_embeddings=rgb[3],
    n_results=2
    #where={"style": "style2"}
)
# Out:
# {'ids': [['3', '2']],
#  'distances': [[0.0, 3891342.0]],
#  'metadatas': [[{'url': 'https://www.youtube.com/watch?v=GnbzWaaIGRY',
#     'wiki': 'A vehicle is a mobile machine that transports people or cargo. Typical vehicles include wagons, bicycles, motor vehicles, railed vehicles, watercraft, aircraft and spacecraft. Land vehicles are classified broadly by what is used to apply steering and drive forces against the ground: wheeled, tracked, railed or skied. ISO 3833-1977 is the standard, also internationally used in legislation, for road vehicles types, terms and definitions.'},
#    {'url': 'https://www.youtube.com/watch?v=jGve-X-fJug',
#     'wiki': "Food is any substance consumed to provide nutritional support for the body. It is usually of plant or animal origin, and contains essential nutrients, such as carbohydrates, fats, proteins, vitamins, or minerals. The substance is ingested by an organism and assimilated by the organism's cells to provide energy, maintain life, or stimulate growth. Historically, people secured food through two methods: hunting and gathering and agriculture. Today, the majority of the food energy required by the ever increasing population of the world is supplied by the food industry. Food safety and food security are monitored by agencies like the International Association for Food Protection, World Resources Institute, World Food Programme, Food and Agriculture Organization, and International Food Information Council. They address issues such as sustainability, biological diversity, climate change, nutritional economics, population growth, water supply, and access to food."}]],
#  'embeddings': None,
#  'documents': [[None, None]],
#  'uris': None,
#  'data': None}

# %%
df.iloc[6]
# Out:
# labels                                                 [0, 1, 234, 1303]
# text_labels                 [Game, Video game, Super Smash Bros., Yoshi]
# url                          https://www.youtube.com/watch?v=DTQpR-AqKnM
# WikiDescription        [A game is structured form of play, usually un...
# text_segment_labels                  [Yoshi, Yoshi, Yoshi, Yoshi, Yoshi]
# segment_labels                            [1303, 1303, 1303, 1303, 1303]
# segment_start_times                             [185, 45, 190, 105, 195]
# segment_end_times                               [190, 50, 195, 110, 200]
# mean_rgb               [181, 16, 82, 162, 190, 255, 88, 28, 202, 213,...
# mean_audio             [156, 218, 194, 148, 121, 42, 8, 73, 68, 35, 9...
# Name: 6, dtype: object

# %%
df.iloc[2]
# Out:
# labels                                            [11, 1366, 1684, 1872]
# text_labels                   [Food, Grocery store, Supermarket, Retail]
# url                          https://www.youtube.com/watch?v=jGve-X-fJug
# WikiDescription        [Food is any substance consumed to provide nut...
# text_segment_labels    [Grocery store, Grocery store, Grocery store, ...
# segment_labels                            [1366, 1366, 1366, 1366, 1366]
# segment_start_times                              [85, 220, 230, 125, 45]
# segment_end_times                                [90, 225, 235, 130, 50]
# mean_rgb               [0, 72, 173, 30, 0, 0, 40, 33, 199, 132, 199, ...
# mean_audio             [175, 47, 132, 85, 169, 168, 156, 167, 157, 13...
# Name: 2, dtype: object

# %%
#!pip install youtube_transcript_api

# %%
youtube_urls

# https://www.youtube.com/watch?v=h06wB5JlyNg
# Out:
# ['https://www.youtube.com/watch?v=KYVAv4gq00k',
#  'https://www.youtube.com/watch?v=Ph-dQZnHChc',
#  'https://www.youtube.com/watch?v=jGve-X-fJug',
#  'https://www.youtube.com/watch?v=GnbzWaaIGRY',
#  'https://www.youtube.com/watch?v=200',
#  'https://www.youtube.com/watch?v=200',
#  'https://www.youtube.com/watch?v=DTQpR-AqKnM',
#  'https://www.youtube.com/watch?v=tTfptynuWdA']

# %%
#!pip install google-api-python-client
#!pip install pytube
# Out:
# Requirement already satisfied: google-api-python-client in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (2.122.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (2.28.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.11.17)
# Requirement already satisfied: pytube in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (15.0.0)

# %% [markdown]
# #### Pull Videos From Lowes Youtube Channel

# %%
from googleapiclient.discovery import build
from pytube import YouTube
import os
from youtube_transcript_api import YouTubeTranscriptApi

# Set up the YouTube Data API
api_key = 'AIzaSyBmGeetqQFiMoDgS4d1Xe7JCTi23yLU2d8'

def get_video_title(video_id, api_key):
    youtube = build('youtube', 'v3', developerKey=api_key)
    request = youtube.videos().list(part='snippet', id=video_id)
    response = request.execute()
    if response['items']:
        return response['items'][0]['snippet']['title']
    else:
        return ''
    
def get_video_transcript(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
        transcript_segments = [
            {
                'start_time': segment['start'],
                'duration': segment['duration'],
                'transcript_text': segment['text']
            }
            for segment in transcript_list
        ]
        return transcript_segments
    except Exception as e:
        print(f"Error extracting transcript for video {video_id}: {e}")
        return []

# %%
api_key = 'AIzaSyBmGeetqQFiMoDgS4d1Xe7JCTi23yLU2d8'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# Get youtube videos from a given channel
# Get the channel ID (replace 'CHANNEL_USERNAME' with the actual username)
channel_response = youtube.channels().list(forUsername='lowes', part='contentDetails').execute()
channel_id = channel_response['items'][0]['id']

# Get the playlist ID for the channel's uploads
uploads_playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# Get the list of video IDs from the uploads playlist
video_ids = []
next_page_token = None
while True:
    playlist_response = youtube.playlistItems().list(playlistId=uploads_playlist_id, part='contentDetails', maxResults=50, pageToken=next_page_token).execute()
    video_ids.extend([item['contentDetails']['videoId'] for item in playlist_response['items']])
    next_page_token = playlist_response.get('nextPageToken')
    if not next_page_token:
        break

# Download the videos using pytube
# download_path = '/Users/runzhu/Desktop/rag/data'
download_path = '/Users/danielcohen/Desktop/RAG/data'
# youtube_url = f"https://www.youtube.com/watch?v={video_id}"
video_info = {}

# Loop through each video ID and extract the transcript
n = 0
max_n = 100
for video_id in video_ids[0:max_n-1]:
    print(video_id)
    title = get_video_title(video_id, api_key)
    transcript = get_video_transcript(video_id)
    i = {'video_title': title,
         'video_transcript': transcript}

    video_info[video_id] = i
# Out:
# hc8ph34dDi4
# 62gTbT_a-bA
# 9erpMbCs1mA
# D9AYFnP8-Kc
# nHMFNj3i5j0
# bsOH6-bWMuU
# cdY-4gH5H-Q
# spcWcQjO-MM
# r92Hyv7T4HM
# 0ON22Q_Eybo
# qbGkLPImZZY
# 9EFo6EKtYUo
# pQ3rDz4BF_Q
# uqzeCY-rr4o
# n73MICun1Dc
# M2PI8PHZw94
# sU4Aoo9GShY
# nn7JjGM_hsE
# nsvVbbYIEZw
# g4f3XzxskEE
# Bhb9Z3-z29g
# tF4NF5QdLn0
# nlYy9STQiZ8
# dUQwgwKFYtk
# CyQZe9W5oOc
# s1j7PZgZKkY
# GiF6Xhfp4v8
# t8AjY8yZ90k
# 2u3HFJ1xzvk
# vVgjJuw8CF8
# HoUsyGjMD38
# K69HPQHg1ZE
# CPey-f0HP4o
# DD113dCPqmg
# FDg183RHzzM
# Error extracting transcript for video FDg183RHzzM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FDg183RHzzM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# CZi4AvG-Y1o
# Error extracting transcript for video CZi4AvG-Y1o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CZi4AvG-Y1o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# gYHMsk3cty0
# oBm55678-ww
# 1GHru4eaJ0s
# irVWA2KTUmE
# h4v4xQZYtPU
# O4dyjvIzbQw
# Gr_msAKEfzU
# ttr-9R3Y3Io
# EeKx5urmDz0
# 8pjaIWtqOQg
# 7F5BUnBDYIE
# UR0azf_PXI0
# 60jWAAdFSGo
# Error extracting transcript for video 60jWAAdFSGo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=60jWAAdFSGo! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (60jWAAdFSGo) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - ar ("Arabic (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - ne ("Nepali")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - or ("Odia")
#  - om ("Oromo")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - ti ("Tigrinya")
#  - ts ("Tsonga")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - vi ("Vietnamese")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# wEpBmesKbws
# avCCtBxH4U4
# Ol1rLQpKJNI
# gJjuNTaxc34
# lTQcnENzFIU
# iCC9hNIMK-k
# Error extracting transcript for video iCC9hNIMK-k:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iCC9hNIMK-k! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# -Ojo7ObonCc
# WB3or8qql_g
# Error extracting transcript for video WB3or8qql_g:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=WB3or8qql_g! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# StoCDKFPJKo
# c1YttW1EnNo
# dGUQpEnsoao
# FoB-oW8q4MI
# ih2jbiCUAsE
# nJe1qmgMBBE
# oTbK1dx4Q0g
# do8NshQKZcY
# 3xpLC5VnS1k
# G3AwNjvI1c0
# jlg3yUqpbFQ
# Zhaj0sCSDys
# S-BCeJAHfFw
# P1xdxliN3Ms
# Sr6w6EfVHsM
# 7ygoDXgUzvY
# rpMwh79HGuQ
# dE0_OrwSPKg
# SEylo88zTaY
# VuYliuENWlw
# wyvUPZ5rb4c
# hkslHfqZRv8
# Ns1T8r1htCc
# WtNlgrNQuN8
# e7euLsxZ810
# yO22CpHihyY
# rCrMDPzAFuI
# 1J7oOHXnoiM
# 0n6zJk-QiVY
# 086fZtoizmc
# fhjPKuQdPrg
# 9tvPeP6O-6M
# Pqhl7802XkM
# bexpEmKKDaQ
# 09718LaV2ig
# gfD-wjCHNqc
# 2DuPnsV_jY4
# paxjcEB3ItQ
# BPhdUVH7NzE
# UloyLzoB9z8
# IHXeiA3p_2w
# sa85vVHV0HE

# %%
video_info
# Out:
# {'hc8ph34dDi4': {'video_title': 'How to Plant Container Pots | How To Anything',
#   'video_transcript': [{'start_time': 0.0,
#     'duration': 3.49,
#     'transcript_text': '[Music]'},
#    {'start_time': 7.799,
#     'duration': 4.041,
#     'transcript_text': "hi everyone I'm Jackie and you're"},
#    {'start_time': 9.599,
#     'duration': 3.92,
#     'transcript_text': "watching Lowe's how to anything it's"},
#    {'start_time': 11.84,
#     'duration': 3.999,
#     'transcript_text': 'springtime so that could only mean one'},
#    {'start_time': 13.519,
#     'duration': 4.801,
#     'transcript_text': 'thing it is the perfect time to plant'},
#    {'start_time': 15.839,
#     'duration': 4.241,
#     'transcript_text': 'new plants more specifically plant them'},
#    {'start_time': 18.32,
#     'duration': 3.16,
#     'transcript_text': "in a container pot so I'm going to walk"},
#    {'start_time': 20.08,
#     'duration': 2.8,
#     'transcript_text': 'you through that process today and not'},
#    {'start_time': 21.48,
#     'duration': 3.44,
#     'transcript_text': "only that I'm going to show you how you"},
#    {'start_time': 22.88,
#     'duration': 4.559,
#     'transcript_text': 'can style them on your front porch to'},
#    {'start_time': 24.92,
#     'duration': 3.72,
#     'transcript_text': "truly celebrate the new season there's a"},
#    {'start_time': 27.439,
#     'duration': 2.6,
#     'transcript_text': 'few things that you want to consider'},
#    {'start_time': 28.64,
#     'duration': 3.36,
#     'transcript_text': "when you're planting your container pot"},
#    {'start_time': 30.039,
#     'duration': 4.721,
#     'transcript_text': 'thoughts the most important what you'},
#    {'start_time': 32.0,
#     'duration': 4.36,
#     'transcript_text': 'should plant each plant has a different'},
#    {'start_time': 34.76,
#     'duration': 3.76,
#     'transcript_text': 'amount of sunlight that it needs to take'},
#    {'start_time': 36.36,
#     'duration': 3.16,
#     'transcript_text': 'in or a different amount of water so'},
#    {'start_time': 38.52,
#     'duration': 2.44,
#     'transcript_text': "when you're grouping together your"},
#    {'start_time': 39.52,
#     'duration': 3.76,
#     'transcript_text': 'plants you want to make sure that they'},
#    {'start_time': 40.96,
#     'duration': 3.8,
#     'transcript_text': 'all require the same amount of care also'},
#    {'start_time': 43.28,
#     'duration': 3.72,
#     'transcript_text': 'make sure you get a container pot that'},
#    {'start_time': 44.76,
#     'duration': 3.56,
#     'transcript_text': 'has a drainage hole another helpful tip'},
#    {'start_time': 47.0,
#     'duration': 3.32,
#     'transcript_text': "if you're putting your container pot on"},
#    {'start_time': 48.32,
#     'duration': 4.36,
#     'transcript_text': 'a hard surface just grab yourself a'},
#    {'start_time': 50.32,
#     'duration': 4.48,
#     'transcript_text': 'wedge like this use it to elevate the'},
#    {'start_time': 52.68,
#     'duration': 4.559,
#     'transcript_text': 'pot which will help drain any excess'},
#    {'start_time': 54.8,
#     'duration': 4.439,
#     'transcript_text': "water in case you're not sure how much"},
#    {'start_time': 57.239,
#     'duration': 3.601,
#     'transcript_text': 'water or sunlight your plant needs in'},
#    {'start_time': 59.239,
#     'duration': 4.0,
#     'transcript_text': 'most cases is your plants will come with'},
#    {'start_time': 60.84,
#     'duration': 4.8,
#     'transcript_text': 'a plant tag and it tells you exactly'},
#    {'start_time': 63.239,
#     'duration': 4.361,
#     'transcript_text': 'what your plant requires all right now'},
#    {'start_time': 65.64,
#     'duration': 3.519,
#     'transcript_text': "that we've gone through all the basics"},
#    {'start_time': 67.6,
#     'duration': 2.96,
#     'transcript_text': "let's get planting when thinking about"},
#    {'start_time': 69.159,
#     'duration': 3.401,
#     'transcript_text': 'how you want to design your container'},
#    {'start_time': 70.56,
#     'duration': 3.96,
#     'transcript_text': 'pot it could be a little overwhelming so'},
#    {'start_time': 72.56,
#     'duration': 4.04,
#     'transcript_text': 'I personally love this method called the'},
#    {'start_time': 74.52,
#     'duration': 3.68,
#     'transcript_text': 'Thriller filler Spiller essentially the'},
#    {'start_time': 76.6,
#     'duration': 3.199,
#     'transcript_text': 'Thriller is going to be the focal point'},
#    {'start_time': 78.2,
#     'duration': 3.919,
#     'transcript_text': 'of your container pot that is going to'},
#    {'start_time': 79.799,
#     'duration': 3.921,
#     'transcript_text': 'be our geranium our filler are the'},
#    {'start_time': 82.119,
#     'duration': 3.481,
#     'transcript_text': "patunas over here that's going to fill"},
#    {'start_time': 83.72,
#     'duration': 3.96,
#     'transcript_text': 'the entire container pot and then the'},
#    {'start_time': 85.6,
#     'duration': 3.96,
#     'transcript_text': "Spiller is our Ivy that's going to spill"},
#    {'start_time': 87.68,
#     'duration': 3.36,
#     'transcript_text': 'over your container pot all three of'},
#    {'start_time': 89.56,
#     'duration': 3.16,
#     'transcript_text': 'these things are going to create the'},
#    {'start_time': 91.04,
#     'duration': 4.32,
#     'transcript_text': "most beautiful design so don't forget"},
#    {'start_time': 92.72,
#     'duration': 4.8,
#     'transcript_text': "the method Thriller filler Spiller it's"},
#    {'start_time': 95.36,
#     'duration': 3.64,
#     'transcript_text': 'never let me down the next thing that'},
#    {'start_time': 97.52,
#     'duration': 3.48,
#     'transcript_text': "we're going to want to do is make sure"},
#    {'start_time': 99.0,
#     'duration': 4.36,
#     'transcript_text': 'that our plants are going to sit right'},
#    {'start_time': 101.0,
#     'duration': 3.439,
#     'transcript_text': 'at the top of our container pot in order'},
#    {'start_time': 103.36,
#     'duration': 3.079,
#     'transcript_text': "for that to happen we're going to need"},
#    {'start_time': 104.439,
#     'duration': 4.401,
#     'transcript_text': 'to fill the bottom with some soil so'},
#    {'start_time': 106.439, 'duration': 4.881, 'transcript_text': "let's do"},
#    {'start_time': 108.84,
#     'duration': 4.879,
#     'transcript_text': 'that I like to use a high quality'},
#    {'start_time': 111.32,
#     'duration': 4.56,
#     'transcript_text': 'potting soil that way my new plants get'},
#    {'start_time': 113.719,
#     'duration': 3.921,
#     'transcript_text': 'the proper nutrients that they need and'},
#    {'start_time': 115.88,
#     'duration': 3.239,
#     'transcript_text': "please don't forget make sure you're"},
#    {'start_time': 117.64,
#     'duration': 3.519,
#     'transcript_text': 'putting your plants at the top of the'},
#    {'start_time': 119.119,
#     'duration': 3.521,
#     'transcript_text': 'container that way when you water them'},
#    {'start_time': 121.159,
#     'duration': 3.28,
#     'transcript_text': "it's not hitting the stems but it's"},
#    {'start_time': 122.64,
#     'duration': 4.119,
#     'transcript_text': 'actually hitting the roots okay I have'},
#    {'start_time': 124.439,
#     'duration': 4.361,
#     'transcript_text': 'this oil where I want it this is a 10 to'},
#    {'start_time': 126.759,
#     'duration': 4.441,
#     'transcript_text': "12 in container pot which means it's"},
#    {'start_time': 128.8,
#     'duration': 4.24,
#     'transcript_text': 'going to fit about 3 to four plants in'},
#    {'start_time': 131.2,
#     'duration': 5.16,
#     'transcript_text': "this container I'm going to start off"},
#    {'start_time': 133.04,
#     'duration': 4.64,
#     'transcript_text': 'with our geranium AKA our Thriller and'},
#    {'start_time': 136.36,
#     'duration': 2.56,
#     'transcript_text': 'that obviously is going to go right in'},
#    {'start_time': 137.68,
#     'duration': 3.44,
#     'transcript_text': "the middle I think I'm going to do one"},
#    {'start_time': 138.92,
#     'duration': 3.679,
#     'transcript_text': 'of the patunas and fill it around and'},
#    {'start_time': 141.12,
#     'duration': 3.6,
#     'transcript_text': 'then one of the ivys again you kind of'},
#    {'start_time': 142.599,
#     'duration': 4.481,
#     'transcript_text': 'want to eye it before you start putting'},
#    {'start_time': 144.72,
#     'duration': 4.12,
#     'transcript_text': 'it in your container just to make sure'},
#    {'start_time': 147.08,
#     'duration': 3.48,
#     'transcript_text': 'you have exactly what you need that'},
#    {'start_time': 148.84,
#     'duration': 3.96,
#     'transcript_text': 'looks about right if I use one of these'},
#    {'start_time': 150.56,
#     'duration': 4.6,
#     'transcript_text': 'to fill it out and one of the ivys the'},
#    {'start_time': 152.8,
#     'duration': 4.24,
#     'transcript_text': 'best way to take a plant out of its pot'},
#    {'start_time': 155.16,
#     'duration': 3.6,
#     'transcript_text': "is to turn it on its side and if it's a"},
#    {'start_time': 157.04,
#     'duration': 3.839,
#     'transcript_text': 'little stuck you could always massage it'},
#    {'start_time': 158.76,
#     'duration': 5.44,
#     'transcript_text': "like this since it's plastic and it'll"},
#    {'start_time': 160.879,
#     'duration': 5.44,
#     'transcript_text': 'just kind of Shuffle out like that all'},
#    {'start_time': 164.2,
#     'duration': 4.16,
#     'transcript_text': 'right as you can see it was in a smaller'},
#    {'start_time': 166.319,
#     'duration': 4.2,
#     'transcript_text': "container so it's Compact and you want"},
#    {'start_time': 168.36,
#     'duration': 3.799,
#     'transcript_text': 'to kind of massage out the soil like'},
#    {'start_time': 170.519,
#     'duration': 3.921,
#     'transcript_text': "this and it's totally okay if some of"},
#    {'start_time': 172.159,
#     'duration': 3.601,
#     'transcript_text': 'the soil falls off replanting it you'},
#    {'start_time': 174.44,
#     'duration': 2.92,
#     'transcript_text': 'just saw how much soy I put in the'},
#    {'start_time': 175.76,
#     'duration': 3.52,
#     'transcript_text': "container pot so you're okay it's good"},
#    {'start_time': 177.36,
#     'duration': 4.84,
#     'transcript_text': "to go now this is the fun part we're"},
#    {'start_time': 179.28,
#     'duration': 7.4,
#     'transcript_text': 'going to grab grab our filler again put'},
#    {'start_time': 182.2,
#     'duration': 7.679,
#     'transcript_text': "it on its side there we go all right I'm"},
#    {'start_time': 186.68,
#     'duration': 6.16,
#     'transcript_text': 'continuing to massage the soil to let'},
#    {'start_time': 189.879,
#     'duration': 5.521,
#     'transcript_text': "the roots breathe so I'm going to place"},
#    {'start_time': 192.84,
#     'duration': 3.959,
#     'transcript_text': 'my filler right next to my Thriller and'},
#    {'start_time': 195.4,
#     'duration': 4.399,
#     'transcript_text': "last we're going to put in our Spiller"},
#    {'start_time': 196.799,
#     'duration': 6.121,
#     'transcript_text': 'The Ivy so the same thing put it on its'},
#    {'start_time': 199.799,
#     'duration': 4.72,
#     'transcript_text': 'side push it out a little bit be gentle'},
#    {'start_time': 202.92,
#     'duration': 4.319,
#     'transcript_text': 'with it there it goes that one just'},
#    {'start_time': 204.519,
#     'duration': 5.601,
#     'transcript_text': 'popped right out and this one we can'},
#    {'start_time': 207.239,
#     'duration': 5.521,
#     'transcript_text': 'spread out a little bit now the only'},
#    {'start_time': 210.12,
#     'duration': 5.759,
#     'transcript_text': 'thing left to do is water our new'},
#    {'start_time': 212.76,
#     'duration': 6.0,
#     'transcript_text': 'container pot and as you can see I am'},
#    {'start_time': 215.879,
#     'duration': 5.241,
#     'transcript_text': 'just focusing the water on the soil not'},
#    {'start_time': 218.76,
#     'duration': 4.679,
#     'transcript_text': 'the actual plants so that it hits The'},
#    {'start_time': 221.12,
#     'duration': 4.08,
#     'transcript_text': 'Roots You could also include a water'},
#    {'start_time': 223.439,
#     'duration': 3.36,
#     'transcript_text': "soluble fertilizer that's going to help"},
#    {'start_time': 225.2,
#     'duration': 3.4,
#     'transcript_text': 'give them the extra nutrients they need'},
#    {'start_time': 226.799, 'duration': 5.68, 'transcript_text': 'so they can'},
#    {'start_time': 228.6, 'duration': 3.879, 'transcript_text': '[Music]'},
#    {'start_time': 235.159,
#     'duration': 5.08,
#     'transcript_text': 'grow the containers are planted the'},
#    {'start_time': 237.84,
#     'duration': 4.239,
#     'transcript_text': "porch is decorated and it's a officially"},
#    {'start_time': 240.239,
#     'duration': 3.761,
#     'transcript_text': 'ready for spring so I went rule of'},
#    {'start_time': 242.079,
#     'duration': 3.24,
#     'transcript_text': 'Threes I got a large pot a medium one'},
#    {'start_time': 244.0,
#     'duration': 3.2,
#     'transcript_text': 'and a small one and put them on both'},
#    {'start_time': 245.319,
#     'duration': 3.76,
#     'transcript_text': 'ends of the porch I also think'},
#    {'start_time': 247.2,
#     'duration': 3.599,
#     'transcript_text': 'accessories go a long way so as you can'},
#    {'start_time': 249.079,
#     'duration': 4.321,
#     'transcript_text': "see I add a little bunny because what's"},
#    {'start_time': 250.799,
#     'duration': 5.08,
#     'transcript_text': 'Green Spring more than a bunny rabbit'},
#    {'start_time': 253.4,
#     'duration': 4.6,
#     'transcript_text': 'and also nothing says welcome home than'},
#    {'start_time': 255.879,
#     'duration': 4.001,
#     'transcript_text': 'a welcome home mat at the end of the day'},
#    {'start_time': 258.0,
#     'duration': 3.6,
#     'transcript_text': 'though it is your porch just have fun'},
#    {'start_time': 259.88,
#     'duration': 3.48,
#     'transcript_text': 'with it thank you guys so much for'},
#    {'start_time': 261.6,
#     'duration': 3.92,
#     'transcript_text': "watching don't forget for all your plant"},
#    {'start_time': 263.36,
#     'duration': 3.04,
#     'transcript_text': "needs just go to your local Lowe's and"},
#    {'start_time': 265.52,
#     'duration': 2.76,
#     'transcript_text': "while you're there if you have any"},
#    {'start_time': 266.4,
#     'duration': 3.6,
#     'transcript_text': "questions at all just find a Lowe's red"},
#    {'start_time': 268.28,
#     'duration': 3.08,
#     'transcript_text': "vest associate they're there to help"},
#    {'start_time': 270.0,
#     'duration': 2.759,
#     'transcript_text': "don't forget to like this video and"},
#    {'start_time': 271.36,
#     'duration': 4.84,
#     'transcript_text': 'leave a comment and let us know what you'},
#    {'start_time': 272.759,
#     'duration': 13.72,
#     'transcript_text': 'want to see on the next howto anything'},
#    {'start_time': 276.2, 'duration': 13.279, 'transcript_text': '[Music]'},
#    {'start_time': 286.479, 'duration': 3.0, 'transcript_text': 'episode'}]},
#  '62gTbT_a-bA': {'video_title': "Don't let the weeds win this season!",
#   'video_transcript': [{'start_time': 0.28,
#     'duration': 3.599,
#     'transcript_text': 'have you ever heard the term'},
#    {'start_time': 1.4,
#     'duration': 5.439,
#     'transcript_text': 'pre-emergent and thought what is that'},
#    {'start_time': 3.879,
#     'duration': 5.041,
#     'transcript_text': "we've got you covered pre-emergent is"},
#    {'start_time': 6.839,
#     'duration': 4.441,
#     'transcript_text': 'basically just a fancy name for a Weed'},
#    {'start_time': 8.92,
#     'duration': 4.52,
#     'transcript_text': 'Preventer pre-emergent is only effective'},
#    {'start_time': 11.28,
#     'duration': 3.72,
#     'transcript_text': 'for 3 months so you need to apply it'},
#    {'start_time': 13.44,
#     'duration': 3.52,
#     'transcript_text': 'seasonally depending on what weeds'},
#    {'start_time': 15.0,
#     'duration': 4.6,
#     'transcript_text': "you're targeting for summer weeds like"},
#    {'start_time': 16.96,
#     'duration': 4.92,
#     'transcript_text': 'crab grass and Ragweed march to April is'},
#    {'start_time': 19.6,
#     'duration': 4.519,
#     'transcript_text': 'the best time to lay it down for winter'},
#    {'start_time': 21.88,
#     'duration': 4.36,
#     'transcript_text': 'weeds like chickweed and Bluegrass early'},
#    {'start_time': 24.119,
#     'duration': 4.24,
#     'transcript_text': 'fall is your sweet spot so put down your'},
#    {'start_time': 26.24,
#     'duration': 4.76,
#     'transcript_text': 'pre-emergent around September or'},
#    {'start_time': 28.359, 'duration': 2.641, 'transcript_text': 'November'}]},
#  '9erpMbCs1mA': {'video_title': 'How to Install a Door: From Start to Finish',
#   'video_transcript': [{'start_time': 0.1,
#     'duration': 3.579,
#     'transcript_text': '[Music]'},
#    {'start_time': 1.88,
#     'duration': 3.52,
#     'transcript_text': 'installing new interior doors can help'},
#    {'start_time': 3.679,
#     'duration': 4.041,
#     'transcript_text': 'improve the quality of your old doors'},
#    {'start_time': 5.4,
#     'duration': 4.0,
#     'transcript_text': "and increase your home's value plus they"},
#    {'start_time': 7.72,
#     'duration': 3.799,
#     'transcript_text': 'can transform the look of your home and'},
#    {'start_time': 9.4,
#     'duration': 4.68,
#     'transcript_text': "make the design more cohesive Lowe's"},
#    {'start_time': 11.519,
#     'duration': 4.401,
#     'transcript_text': 'offers slab and prehung Doors today'},
#    {'start_time': 14.08,
#     'duration': 4.4,
#     'transcript_text': "we'll be using Masonite they have a"},
#    {'start_time': 15.92,
#     'duration': 4.519,
#     'transcript_text': 'variety of types Styles colors and'},
#    {'start_time': 18.48,
#     'duration': 6.2,
#     'transcript_text': "Hardware finishes here's what you need"},
#    {'start_time': 20.439,
#     'duration': 4.241,
#     'transcript_text': 'to know to install a prehung interior'},
#    {'start_time': 26.32,
#     'duration': 4.279,
#     'transcript_text': 'door to start check the current'},
#    {'start_time': 29.0,
#     'duration': 3.32,
#     'transcript_text': 'condition of the door and frame to'},
#    {'start_time': 30.599,
#     'duration': 4.12,
#     'transcript_text': "decide what type of replacement you'll"},
#    {'start_time': 32.32,
#     'duration': 4.559,
#     'transcript_text': 'make if the frame is in good condition'},
#    {'start_time': 34.719,
#     'duration': 4.441,
#     'transcript_text': 'and you want to replace just the door'},
#    {'start_time': 36.879,
#     'duration': 4.121,
#     'transcript_text': 'that will be a door slab replacement the'},
#    {'start_time': 39.16,
#     'duration': 4.36,
#     'transcript_text': 'installation requires cutting mortises'},
#    {'start_time': 41.0,
#     'duration': 4.52,
#     'transcript_text': 'for the hinges if the frame is damaged'},
#    {'start_time': 43.52,
#     'duration': 4.199,
#     'transcript_text': "or your door doesn't swing correctly"},
#    {'start_time': 45.52,
#     'duration': 4.679,
#     'transcript_text': "you'll want to do a prehung installation"},
#    {'start_time': 47.719,
#     'duration': 5.36,
#     'transcript_text': 'a prehung door includes the frame door'},
#    {'start_time': 50.199,
#     'duration': 5.401,
#     'transcript_text': 'slab and hinges the installation is'},
#    {'start_time': 53.079,
#     'duration': 4.881,
#     'transcript_text': 'typically easier than installing a slab'},
#    {'start_time': 55.6,
#     'duration': 5.08,
#     'transcript_text': "we're installing a prehung solid core"},
#    {'start_time': 57.96,
#     'duration': 4.64,
#     'transcript_text': "door to buy a prehung door you'll need"},
#    {'start_time': 60.68,
#     'duration': 4.0,
#     'transcript_text': 'to know the swing Direction and door'},
#    {'start_time': 62.6,
#     'duration': 4.199,
#     'transcript_text': 'size to determine the swing with the'},
#    {'start_time': 64.68,
#     'duration': 5.32,
#     'transcript_text': 'door open stand with your back to the'},
#    {'start_time': 66.799,
#     'duration': 5.081,
#     'transcript_text': 'hinges the side that the handle is on is'},
#    {'start_time': 70.0,
#     'duration': 4.32,
#     'transcript_text': 'the door swing in our case we have a'},
#    {'start_time': 71.88, 'duration': 2.44, 'transcript_text': 'leftand'},
#    {'start_time': 74.68, 'duration': 4.28, 'transcript_text': '[Music]'},
#    {'start_time': 76.24,
#     'duration': 4.48,
#     'transcript_text': "door next measure for the new door it's"},
#    {'start_time': 78.96,
#     'duration': 4.72,
#     'transcript_text': 'important to get an accurate measurement'},
#    {'start_time': 80.72,
#     'duration': 5.16,
#     'transcript_text': 'to 1/16th of an inch check twice to be'},
#    {'start_time': 83.68,
#     'duration': 4.439,
#     'transcript_text': 'sure the rough opening is the stud'},
#    {'start_time': 85.88,
#     'duration': 4.239,
#     'transcript_text': 'framing that surrounds the door frame it'},
#    {'start_time': 88.119,
#     'duration': 4.521,
#     'transcript_text': 'can be helpful to know those dimensions'},
#    {'start_time': 90.119,
#     'duration': 5.201,
#     'transcript_text': 'when purchasing a door however doors are'},
#    {'start_time': 92.64,
#     'duration': 4.759,
#     'transcript_text': 'available in standard sizes so your old'},
#    {'start_time': 95.32,
#     'duration': 5.04,
#     'transcript_text': 'door slab can typically be used as a'},
#    {'start_time': 97.399,
#     'duration': 5.36,
#     'transcript_text': 'guide the door slab will be about 2 and'},
#    {'start_time': 100.36,
#     'duration': 5.799,
#     'transcript_text': '1/2 in less in width than the rough'},
#    {'start_time': 102.759,
#     'duration': 6.281,
#     'transcript_text': 'opening and 2 and 1/4 in less in height'},
#    {'start_time': 106.159,
#     'duration': 5.681,
#     'transcript_text': 'also check the depth typically interior'},
#    {'start_time': 109.04,
#     'duration': 5.2,
#     'transcript_text': 'door jams are 4 and 9/16 to match the'},
#    {'start_time': 111.84,
#     'duration': 4.199,
#     'transcript_text': 'depth of the wall stud and drywall give'},
#    {'start_time': 114.24,
#     'duration': 3.199,
#     'transcript_text': "these measurements to a Lo's associate"},
#    {'start_time': 116.039,
#     'duration': 2.801,
#     'transcript_text': 'who can help determine the best door'},
#    {'start_time': 117.439,
#     'duration': 4.401,
#     'transcript_text': 'size for your'},
#    {'start_time': 118.84, 'duration': 3.0, 'transcript_text': 'project'},
#    {'start_time': 123.0,
#     'duration': 4.32,
#     'transcript_text': "so we have our new door we're installing"},
#    {'start_time': 124.88,
#     'duration': 4.999,
#     'transcript_text': 'the Masonite Logan two panel solid core'},
#    {'start_time': 127.32,
#     'duration': 4.919,
#     'transcript_text': 'door Masonite solid core doors feature'},
#    {'start_time': 129.879,
#     'duration': 4.72,
#     'transcript_text': '70% more Sound Reduction materials than'},
#    {'start_time': 132.239,
#     'duration': 4.521,
#     'transcript_text': 'its standard Hollow core doors which can'},
#    {'start_time': 134.599,
#     'duration': 3.681,
#     'transcript_text': 'significantly help with noise control'},
#    {'start_time': 136.76,
#     'duration': 4.36,
#     'transcript_text': 'these doors are a great option for a'},
#    {'start_time': 138.28,
#     'duration': 5.08,
#     'transcript_text': 'noisy laundry room office bathroom or'},
#    {'start_time': 141.12,
#     'duration': 4.32,
#     'transcript_text': 'even a bedroom for a quieter night sleep'},
#    {'start_time': 143.36,
#     'duration': 5.48,
#     'transcript_text': 'whichever type of door you do install'},
#    {'start_time': 145.44,
#     'duration': 6.36,
#     'transcript_text': "always follow the manufacturer's"},
#    {'start_time': 148.84,
#     'duration': 5.119,
#     'transcript_text': 'instructions'},
#    {'start_time': 151.8,
#     'duration': 4.56,
#     'transcript_text': 'to remove the slab tap out the hinge'},
#    {'start_time': 153.959,
#     'duration': 4.721,
#     'transcript_text': 'pins with a screwdriver or a nail set'},
#    {'start_time': 156.36,
#     'duration': 5.4,
#     'transcript_text': 'and a hammer pop the old door off and'},
#    {'start_time': 158.68,
#     'duration': 4.479,
#     'transcript_text': 'set it aside next remove the casing by'},
#    {'start_time': 161.76,
#     'duration': 3.88,
#     'transcript_text': 'carefully scoring the paint with the'},
#    {'start_time': 163.159,
#     'duration': 5.44,
#     'transcript_text': 'utility knife then use a putty knife or'},
#    {'start_time': 165.64,
#     'duration': 4.48,
#     'transcript_text': 'a pry bar to pull off the casing take'},
#    {'start_time': 168.599,
#     'duration': 4.201,
#     'transcript_text': "care when doing this in case you're"},
#    {'start_time': 170.12, 'duration': 2.68, 'transcript_text': 'reusing the'},
#    {'start_time': 173.84,
#     'duration': 5.0,
#     'transcript_text': 'casing remove any nails or screws'},
#    {'start_time': 176.48,
#     'duration': 4.28,
#     'transcript_text': 'holding the old door jams in'},
#    {'start_time': 178.84, 'duration': 3.679, 'transcript_text': 'place'},
#    {'start_time': 180.76,
#     'duration': 3.68,
#     'transcript_text': 'if needed cut them between the door'},
#    {'start_time': 182.519,
#     'duration': 4.201,
#     'transcript_text': 'frame and the rough opening studs with a'},
#    {'start_time': 184.44,
#     'duration': 4.719,
#     'transcript_text': 'reciprocating saw then pull out the old'},
#    {'start_time': 186.72, 'duration': 2.439, 'transcript_text': 'frame and'},
#    {'start_time': 189.39, 'duration': 4.929, 'transcript_text': '[Music]'},
#    {'start_time': 191.76,
#     'duration': 3.6,
#     'transcript_text': 'shims to prep the rough opening clean'},
#    {'start_time': 194.319, 'duration': 3.241, 'transcript_text': 'away any'},
#    {'start_time': 195.36,
#     'duration': 4.08,
#     'transcript_text': 'debris check the rough opening for'},
#    {'start_time': 197.56, 'duration': 4.48, 'transcript_text': 'square and'},
#    {'start_time': 199.44,
#     'duration': 4.84,
#     'transcript_text': 'Plum also check the floor for level in'},
#    {'start_time': 202.04,
#     'duration': 4.16,
#     'transcript_text': 'the doorway if the floor is uneven in'},
#    {'start_time': 204.28,
#     'duration': 4.48,
#     'transcript_text': 'the doorway shims can be used to raise'},
#    {'start_time': 206.2,
#     'duration': 4.8,
#     'transcript_text': "the jams if needed if one side's low"},
#    {'start_time': 208.76,
#     'duration': 4.8,
#     'transcript_text': 'hold a Long Level AC cross the framing'},
#    {'start_time': 211.0,
#     'duration': 4.2,
#     'transcript_text': 'Mark both sides of the opening measure'},
#    {'start_time': 213.56,
#     'duration': 3.319,
#     'transcript_text': 'up from the floor to each Mark to see'},
#    {'start_time': 215.2,
#     'duration': 3.399,
#     'transcript_text': 'the difference in height this can help'},
#    {'start_time': 216.879,
#     'duration': 4.28,
#     'transcript_text': 'determine how high to lift one side of'},
#    {'start_time': 218.599,
#     'duration': 4.2,
#     'transcript_text': 'the new door frame to make it Square'},
#    {'start_time': 221.159,
#     'duration': 3.761,
#     'transcript_text': 'also use a level to check the clearance'},
#    {'start_time': 222.799,
#     'duration': 4.52,
#     'transcript_text': "where the door will swing it's also not"},
#    {'start_time': 224.92,
#     'duration': 4.239,
#     'transcript_text': 'a bad idea to check the walls for Plum'},
#    {'start_time': 227.319,
#     'duration': 3.361,
#     'transcript_text': 'if they are off a little bit remember'},
#    {'start_time': 229.159,
#     'duration': 4.44,
#     'transcript_text': 'the new door frame must be installed'},
#    {'start_time': 230.68, 'duration': 2.919, 'transcript_text': 'Plum and'},
#    {'start_time': 235.879,
#     'duration': 5.681,
#     'transcript_text': "square there's several ways to install"},
#    {'start_time': 238.72,
#     'duration': 5.96,
#     'transcript_text': 'doors kits are available that install to'},
#    {'start_time': 241.56,
#     'duration': 5.84,
#     'transcript_text': 'the door jam and then to the wall or you'},
#    {'start_time': 244.68,
#     'duration': 5.16,
#     'transcript_text': 'could use shims to create a firm baging'},
#    {'start_time': 247.4,
#     'duration': 4.72,
#     'transcript_text': 'between the jam and the rough opening to'},
#    {'start_time': 249.84,
#     'duration': 4.28,
#     'transcript_text': 'start remove just the threaded insert'},
#    {'start_time': 252.12,
#     'duration': 4.92,
#     'transcript_text': 'from the shipping plug then set the new'},
#    {'start_time': 254.12,
#     'duration': 4.639,
#     'transcript_text': 'door unit into the frame bottom first'},
#    {'start_time': 257.04,
#     'duration': 4.68,
#     'transcript_text': 'then Center the new unit in the rough'},
#    {'start_time': 258.759,
#     'duration': 4.361,
#     'transcript_text': 'opening it should be flush with the wall'},
#    {'start_time': 261.72,
#     'duration': 4.24,
#     'transcript_text': 'now we can pop out the rest of the'},
#    {'start_time': 263.12,
#     'duration': 5.44,
#     'transcript_text': 'shipping plug slightly open the door and'},
#    {'start_time': 265.96,
#     'duration': 5.239,
#     'transcript_text': 'clamp the top just to hold'},
#    {'start_time': 268.56,
#     'duration': 4.96,
#     'transcript_text': 'it then then support the door with shims'},
#    {'start_time': 271.199,
#     'duration': 4.961,
#     'transcript_text': 'to keep it from swinging use a level to'},
#    {'start_time': 273.52,
#     'duration': 4.519,
#     'transcript_text': 'check the jams for Plum shims will be'},
#    {'start_time': 276.16,
#     'duration': 4.16,
#     'transcript_text': 'installed at the hinge locations and'},
#    {'start_time': 278.039,
#     'duration': 4.88,
#     'transcript_text': 'also the strike side secure the frame on'},
#    {'start_time': 280.32,
#     'duration': 4.599,
#     'transcript_text': 'the hinge side first at the top hinge'},
#    {'start_time': 282.919,
#     'duration': 4.361,
#     'transcript_text': 'insert shims behind the jam from each'},
#    {'start_time': 284.919,
#     'duration': 3.641,
#     'transcript_text': 'side overlapping behind the frame this'},
#    {'start_time': 287.28,
#     'duration': 3.759,
#     'transcript_text': 'will help prevent the frame from'},
#    {'start_time': 288.56,
#     'duration': 5.16,
#     'transcript_text': 'twisting and binding check that the unit'},
#    {'start_time': 291.039,
#     'duration': 6.44,
#     'transcript_text': 'is plum drill pilot'},
#    {'start_time': 293.72,
#     'duration': 7.919,
#     'transcript_text': 'holes and drive the screws into the'},
#    {'start_time': 297.479,
#     'duration': 4.16,
#     'transcript_text': 'studs repeat at the bottom Hing'},
#    {'start_time': 304.039,
#     'duration': 6.44,
#     'transcript_text': 'and check for square and'},
#    {'start_time': 306.919,
#     'duration': 5.681,
#     'transcript_text': 'Plum then secure behind the middle hinge'},
#    {'start_time': 310.479,
#     'duration': 4.601,
#     'transcript_text': 'frequently check for Plum and square as'},
#    {'start_time': 312.6,
#     'duration': 4.8,
#     'transcript_text': 'you install if you check as you go you'},
#    {'start_time': 315.08,
#     'duration': 5.16,
#     'transcript_text': 'might have less adjustments to make next'},
#    {'start_time': 317.4,
#     'duration': 5.44,
#     'transcript_text': 'remove the clamp and check that the door'},
#    {'start_time': 320.24,
#     'duration': 4.48,
#     'transcript_text': 'closes properly and has an even reveal'},
#    {'start_time': 322.84,
#     'duration': 4.479,
#     'transcript_text': 'if not open the door and double check'},
#    {'start_time': 324.72,
#     'duration': 5.199,
#     'transcript_text': 'that the hinge side is plum and'},
#    {'start_time': 327.319,
#     'duration': 4.201,
#     'transcript_text': 'square if the hinge side looks good you'},
#    {'start_time': 329.919,
#     'duration': 3.441,
#     'transcript_text': 'might have to raise the strike side of'},
#    {'start_time': 331.52,
#     'duration': 4.2,
#     'transcript_text': 'the jam using a shim to make sure the'},
#    {'start_time': 333.36,
#     'duration': 4.679,
#     'transcript_text': "entire frame is square you'll know this"},
#    {'start_time': 335.72,
#     'duration': 4.16,
#     'transcript_text': 'if you check the floor for level earlier'},
#    {'start_time': 338.039,
#     'duration': 4.041,
#     'transcript_text': 'on the strike side of the jam Place'},
#    {'start_time': 339.88,
#     'duration': 5.92,
#     'transcript_text': 'shims just behind the strike plate and'},
#    {'start_time': 342.08,
#     'duration': 6.2,
#     'transcript_text': 'check the reveal then check for Plum and'},
#    {'start_time': 345.8, 'duration': 2.48, 'transcript_text': 'secure with'},
#    {'start_time': 348.84,
#     'duration': 4.56,
#     'transcript_text': 'screws secure the shims near the top and'},
#    {'start_time': 351.6,
#     'duration': 3.8,
#     'transcript_text': 'bottom of the strike side Jam just like'},
#    {'start_time': 353.4,
#     'duration': 4.519,
#     'transcript_text': 'you did on the hinge'},
#    {'start_time': 355.4,
#     'duration': 4.28,
#     'transcript_text': 'side then carefully install shims and'},
#    {'start_time': 357.919,
#     'duration': 3.081,
#     'transcript_text': "screws at the header but don't"},
#    {'start_time': 359.68,
#     'duration': 2.959,
#     'transcript_text': 'overtighten them it might bend the'},
#    {'start_time': 361.0,
#     'duration': 3.639,
#     'transcript_text': 'framing check that the door works'},
#    {'start_time': 362.639,
#     'duration': 4.081,
#     'transcript_text': 'properly one more time and adjust if'},
#    {'start_time': 364.639,
#     'duration': 3.521,
#     'transcript_text': 'needed then cut the excess shims with a'},
#    {'start_time': 366.72, 'duration': 5.319, 'transcript_text': 'utility'},
#    {'start_time': 368.16,
#     'duration': 3.879,
#     'transcript_text': 'knife or an oscillating'},
#    {'start_time': 375.84,
#     'duration': 4.28,
#     'transcript_text': "tool with our door installed we're ready"},
#    {'start_time': 378.24,
#     'duration': 3.679,
#     'transcript_text': "to move on to the finishing steps we're"},
#    {'start_time': 380.12,
#     'duration': 3.02,
#     'transcript_text': 'going to start by reattaching our trim'},
#    {'start_time': 381.919,
#     'duration': 3.161,
#     'transcript_text': 'using finishing'},
#    {'start_time': 383.14, 'duration': 5.1, 'transcript_text': '[Music]'},
#    {'start_time': 385.08,
#     'duration': 4.66,
#     'transcript_text': 'nails apply caul along the gaps and fill'},
#    {'start_time': 388.24,
#     'duration': 3.2,
#     'transcript_text': 'the nail holes'},
#    {'start_time': 389.74, 'duration': 3.62, 'transcript_text': '[Music]'},
#    {'start_time': 391.44,
#     'duration': 3.72,
#     'transcript_text': 'the next step is paint this door and'},
#    {'start_time': 393.36,
#     'duration': 4.119,
#     'transcript_text': 'frame are already primed and ready for'},
#    {'start_time': 395.16,
#     'duration': 3.759,
#     'transcript_text': 'paint doors can be painted in place just'},
#    {'start_time': 397.479,
#     'duration': 3.801,
#     'transcript_text': 'be sure to protect the hinges with'},
#    {'start_time': 398.919,
#     'duration': 4.501,
#     'transcript_text': 'painters tape we removed Ours from the'},
#    {'start_time': 401.28,
#     'duration': 4.84,
#     'transcript_text': 'hinges and painted it on saw'},
#    {'start_time': 403.42, 'duration': 5.54, 'transcript_text': '[Music]'},
#    {'start_time': 406.12,
#     'duration': 5.16,
#     'transcript_text': 'horses install the matching lock set'},
#    {'start_time': 408.96,
#     'duration': 4.679,
#     'transcript_text': "following the manufacturer's"},
#    {'start_time': 411.28,
#     'duration': 4.28,
#     'transcript_text': 'instructions and now the installation is'},
#    {'start_time': 413.639,
#     'duration': 4.12,
#     'transcript_text': 'complete if you do need help with this'},
#    {'start_time': 415.56,
#     'duration': 4.52,
#     'transcript_text': 'project Los has independent installers'},
#    {'start_time': 417.759,
#     'duration': 4.481,
#     'transcript_text': 'ready to help you get the job done we'},
#    {'start_time': 420.08,
#     'duration': 4.48,
#     'transcript_text': 'remove the old door prep the rough'},
#    {'start_time': 422.24,
#     'duration': 4.88,
#     'transcript_text': 'opening and install a new Masonite solid'},
#    {'start_time': 424.56,
#     'duration': 4.24,
#     'transcript_text': 'core door a new prehung solid core door'},
#    {'start_time': 427.12,
#     'duration': 3.759,
#     'transcript_text': 'can help enhance the look of your home'},
#    {'start_time': 428.8,
#     'duration': 3.92,
#     'transcript_text': 'and offer peace and quiet thanks for'},
#    {'start_time': 430.879,
#     'duration': 3.521,
#     'transcript_text': 'watching comment below with any'},
#    {'start_time': 432.72,
#     'duration': 4.0,
#     'transcript_text': 'questions or thoughts on this DIY'},
#    {'start_time': 434.4,
#     'duration': 3.88,
#     'transcript_text': 'project click that subscribe button and'},
#    {'start_time': 436.72,
#     'duration': 3.879,
#     'transcript_text': "let us know what project you'd like to"},
#    {'start_time': 438.28, 'duration': 2.319, 'transcript_text': 'see'},
#    {'start_time': 445.879, 'duration': 3.0, 'transcript_text': 'next'}]},
#  'D9AYFnP8-Kc': {'video_title': 'Crucial information!',
#   'video_transcript': [{'start_time': 0.08,
#     'duration': 3.599,
#     'transcript_text': "here's a hack to make sure your Spring"},
#    {'start_time': 1.599,
#     'duration': 3.921,
#     'transcript_text': "Garden thrives this season it's easier"},
#    {'start_time': 3.679,
#     'duration': 3.521,
#     'transcript_text': "than you think look for Lowe's grow"},
#    {'start_time': 5.52,
#     'duration': 4.159,
#     'transcript_text': 'together tags plants that have the same'},
#    {'start_time': 7.2,
#     'duration': 4.16,
#     'transcript_text': "number we'll grow well together these"},
#    {'start_time': 9.679,
#     'duration': 3.241,
#     'transcript_text': 'tags will show the name of your plant'},
#    {'start_time': 11.36,
#     'duration': 3.76,
#     'transcript_text': 'the amount of water and sunlight it'},
#    {'start_time': 12.92,
#     'duration': 4.119,
#     'transcript_text': 'needs how big it will grow and the type'},
#    {'start_time': 15.12,
#     'duration': 3.64,
#     'transcript_text': 'of environment it will grow best in and'},
#    {'start_time': 17.039,
#     'duration': 3.921,
#     'transcript_text': 'if you accidentally threw out your plant'},
#    {'start_time': 18.76,
#     'duration': 3.8,
#     'transcript_text': "tag Don't Panic search for your plant on"},
#    {'start_time': 20.96,
#     'duration': 2.84,
#     'transcript_text': "the Lowe's app and you'll find all of"},
#    {'start_time': 22.56,
#     'duration': 6.24,
#     'transcript_text': 'this information under the'},
#    {'start_time': 23.8,
#     'duration': 5.0,
#     'transcript_text': 'specifications tab happy planting'}]},
#  'nHMFNj3i5j0': {'video_title': 'How To Paint Cabinets | A Step-by-Step Guide',
#   'video_transcript': [{'start_time': 0.4,
#     'duration': 4.0,
#     'transcript_text': '[Music]'},
#    {'start_time': 1.839,
#     'duration': 4.0,
#     'transcript_text': "this is Ty and Shai and I'm Andrew they"},
#    {'start_time': 4.4,
#     'duration': 3.64,
#     'transcript_text': "want to renovate their kitchen so I'm"},
#    {'start_time': 5.839,
#     'duration': 4.88,
#     'transcript_text': 'here to help them through the process'},
#    {'start_time': 8.04,
#     'duration': 5.559,
#     'transcript_text': "this is Tai and Shai's house and this is"},
#    {'start_time': 10.719,
#     'duration': 4.441,
#     'transcript_text': 'their kitchen Welcome to our kitchen Tai'},
#    {'start_time': 13.599,
#     'duration': 3.881,
#     'transcript_text': 'and Shai tiled their floors and their'},
#    {'start_time': 15.16,
#     'duration': 5.32,
#     'transcript_text': 'backsplash in the last DIY videos and'},
#    {'start_time': 17.48,
#     'duration': 3.0,
#     'transcript_text': "now they're ready to paint their"},
#    {'start_time': 20.6,
#     'duration': 7.4,
#     'transcript_text': 'cabinets so here we go how to paint'},
#    {'start_time': 25.24,
#     'duration': 3.84,
#     'transcript_text': 'cabinets so first things first tell me a'},
#    {'start_time': 28.0,
#     'duration': 2.679,
#     'transcript_text': 'little bit about the state of your'},
#    {'start_time': 29.08,
#     'duration': 2.72,
#     'transcript_text': 'cabinets do you know what kind of wood'},
#    {'start_time': 30.679,
#     'duration': 2.921,
#     'transcript_text': "they are or what they're currently"},
#    {'start_time': 31.8,
#     'duration': 4.36,
#     'transcript_text': 'painted with I think our cabinets are'},
#    {'start_time': 33.6,
#     'duration': 4.68,
#     'transcript_text': "Oak and they're currently varnished so"},
#    {'start_time': 36.16,
#     'duration': 3.28,
#     'transcript_text': "that limits your options just a bit it's"},
#    {'start_time': 38.28,
#     'duration': 2.72,
#     'transcript_text': 'pretty hard to paint over varnish'},
#    {'start_time': 39.44,
#     'duration': 4.0,
#     'transcript_text': 'cabinets unless you fully strip off the'},
#    {'start_time': 41.0,
#     'duration': 4.36,
#     'transcript_text': 'varnish and sand down the cabinets quite'},
#    {'start_time': 43.44,
#     'duration': 3.68,
#     'transcript_text': "frankly it's a lot of work but lucky for"},
#    {'start_time': 45.36,
#     'duration': 3.24,
#     'transcript_text': 'you those carries a primer made for'},
#    {'start_time': 47.12,
#     'duration': 2.8,
#     'transcript_text': 'varnish cabinets so you can go straight'},
#    {'start_time': 48.6, 'duration': 3.0, 'transcript_text': 'to'},
#    {'start_time': 49.92,
#     'duration': 3.36,
#     'transcript_text': 'painting here are the tools and'},
#    {'start_time': 51.6,
#     'duration': 3.84,
#     'transcript_text': 'materials Tai and shy will need to paint'},
#    {'start_time': 53.28, 'duration': 2.16, 'transcript_text': 'their'},
#    {'start_time': 56.079,
#     'duration': 5.44,
#     'transcript_text': "cabinets first let's start by taking off"},
#    {'start_time': 58.32,
#     'duration': 4.719,
#     'transcript_text': 'the cabinet doors and drawers'},
#    {'start_time': 61.519,
#     'duration': 3.96,
#     'transcript_text': "we're going to need to fill some of the"},
#    {'start_time': 63.039,
#     'duration': 4.641,
#     'transcript_text': 'dents with wood filler but other than'},
#    {'start_time': 65.479,
#     'duration': 4.481,
#     'transcript_text': "that they're in pretty good shape good"},
#    {'start_time': 67.68,
#     'duration': 5.32,
#     'transcript_text': 'call if you have Nicks bumps or divots'},
#    {'start_time': 69.96,
#     'duration': 6.479,
#     'transcript_text': "in the surfaces you'll need to repair"},
#    {'start_time': 73.0,
#     'duration': 5.04,
#     'transcript_text': "them first sand the wood surface you'll"},
#    {'start_time': 76.439,
#     'duration': 4.281,
#     'transcript_text': 'want to be sure to wipe away any dust'},
#    {'start_time': 78.04,
#     'duration': 5.2,
#     'transcript_text': 'with a clean cloth use a putty knife to'},
#    {'start_time': 80.72,
#     'duration': 3.96,
#     'transcript_text': 'spread wood filler over the damage and'},
#    {'start_time': 83.24,
#     'duration': 3.8,
#     'transcript_text': 'then allow it to'},
#    {'start_time': 84.68,
#     'duration': 3.799,
#     'transcript_text': "dry for cabinet doors you're going to"},
#    {'start_time': 87.04,
#     'duration': 5.32,
#     'transcript_text': 'want to clean the whole surface with a'},
#    {'start_time': 88.479,
#     'duration': 6.28,
#     'transcript_text': 'heavy duty cleaner before you Prime like'},
#    {'start_time': 92.36,
#     'duration': 4.079,
#     'transcript_text': 'tsp Tai and shy are going to use that'},
#    {'start_time': 94.759,
#     'duration': 3.36,
#     'transcript_text': 'specialty primer for their varnish'},
#    {'start_time': 96.439,
#     'duration': 3.72,
#     'transcript_text': "cabinets but if you're painting"},
#    {'start_time': 98.119,
#     'duration': 4.601,
#     'transcript_text': 'unvarnished cabinets with standard paint'},
#    {'start_time': 100.159,
#     'duration': 5.56,
#     'transcript_text': 'the steps are the same use a mini roller'},
#    {'start_time': 102.72,
#     'duration': 4.92,
#     'transcript_text': 'on large flat areas remember primer'},
#    {'start_time': 105.719,
#     'duration': 3.36,
#     'transcript_text': "doesn't have to look perfect its purpose"},
#    {'start_time': 107.64,
#     'duration': 3.28,
#     'transcript_text': 'is to cover the surface and provide a'},
#    {'start_time': 109.079,
#     'duration': 5.521,
#     'transcript_text': 'good base for the Finish'},
#    {'start_time': 110.92,
#     'duration': 6.879,
#     'transcript_text': 'paint work on one area at a time on the'},
#    {'start_time': 114.6,
#     'duration': 4.4,
#     'transcript_text': 'cabinet frames work from inside out if'},
#    {'start_time': 117.799,
#     'duration': 2.96,
#     'transcript_text': "you're painting on the inside of the"},
#    {'start_time': 119.0,
#     'duration': 3.52,
#     'transcript_text': 'cabinets start at the back and work'},
#    {'start_time': 120.759, 'duration': 4.04, 'transcript_text': 'towards the'},
#    {'start_time': 122.52,
#     'duration': 4.48,
#     'transcript_text': 'front use a brush to get into corners'},
#    {'start_time': 124.799,
#     'duration': 4.441,
#     'transcript_text': "and detailed areas it's important to use"},
#    {'start_time': 127.0, 'duration': 2.24, 'transcript_text': 'even'},
#    {'start_time': 132.04,
#     'duration': 4.12,
#     'transcript_text': 'Strokes okay now that you primed all'},
#    {'start_time': 134.56,
#     'duration': 4.2,
#     'transcript_text': 'your surfaces do you know what paint'},
#    {'start_time': 136.16,
#     'duration': 5.28,
#     'transcript_text': 'color and finish you want we chose white'},
#    {'start_time': 138.76,
#     'duration': 4.8,
#     'transcript_text': 'because we wanted to add more light to'},
#    {'start_time': 141.44,
#     'duration': 3.36,
#     'transcript_text': 'the space but also complement the tiles'},
#    {'start_time': 143.56,
#     'duration': 3.2,
#     'transcript_text': "that we're putting in both for the"},
#    {'start_time': 144.8,
#     'duration': 3.76,
#     'transcript_text': 'floors and the backsplash do you have a'},
#    {'start_time': 146.76,
#     'duration': 4.72,
#     'transcript_text': 'recommendation for what type of finish'},
#    {'start_time': 148.56,
#     'duration': 5.64,
#     'transcript_text': 'we should use totally a matte finish'},
#    {'start_time': 151.48,
#     'duration': 4.52,
#     'transcript_text': 'gives a flatter low gloss finish a high'},
#    {'start_time': 154.2,
#     'duration': 4.84,
#     'transcript_text': 'gloss finish on the other hand provides'},
#    {'start_time': 156.0,
#     'duration': 5.28,
#     'transcript_text': 'a high sheet and a satin finish Falls'},
#    {'start_time': 159.04,
#     'duration': 4.52,
#     'transcript_text': 'between the two semi gloss and satin'},
#    {'start_time': 161.28,
#     'duration': 3.879,
#     'transcript_text': 'finishes are typically used in kitchens'},
#    {'start_time': 163.56,
#     'duration': 3.319,
#     'transcript_text': 'a gloss finish will give your cabinets a'},
#    {'start_time': 165.159,
#     'duration': 4.041,
#     'transcript_text': 'lot of Sheen but it may show a lot of'},
#    {'start_time': 166.879,
#     'duration': 5.401,
#     'transcript_text': 'dings and mistakes and some flat finish'},
#    {'start_time': 169.2,
#     'duration': 3.08,
#     'transcript_text': 'paints can be difficult to'},
#    {'start_time': 173.0,
#     'duration': 4.8,
#     'transcript_text': 'clean we ended up going with this'},
#    {'start_time': 175.519,
#     'duration': 5.241,
#     'transcript_text': 'beastro white cabinet paint with the'},
#    {'start_time': 177.8,
#     'duration': 4.719,
#     'transcript_text': 'satin finish by vpar'},
#    {'start_time': 180.76,
#     'duration': 3.6,
#     'transcript_text': 'Tai and Shai also decided to paint their'},
#    {'start_time': 182.519,
#     'duration': 3.64,
#     'transcript_text': 'lower cabinets green to complement the'},
#    {'start_time': 184.36,
#     'duration': 4.12,
#     'transcript_text': 'color of their new terra cotta'},
#    {'start_time': 186.159,
#     'duration': 4.241,
# ...
#    {'start_time': 622.8,
#     'duration': 4.8,
#     'transcript_text': 'the room these brackets are gonna go'},
#    {'start_time': 625.2,
#     'duration': 5.34,
#     'transcript_text': 'into the ceiling I already have two'},
#    {'start_time': 627.6,
#     'duration': 5.1,
#     'transcript_text': 'anchors in there I kind of think of'},
#    {'start_time': 630.54,
#     'duration': 3.9,
#     'transcript_text': 'curtains as like drawing attention to'},
#    {'start_time': 632.7,
#     'duration': 3.9,
#     'transcript_text': "something not covering it up so it's"},
#    {'start_time': 634.44,
#     'duration': 3.78,
#     'transcript_text': 'kind of like a movie theater or stage'},
#    {'start_time': 636.6,
#     'duration': 3.66,
#     'transcript_text': 'the curtains on the side kind of direct'},
#    {'start_time': 638.22,
#     'duration': 4.86,
#     'transcript_text': 'you towards what the main main action is'},
#    {'start_time': 640.26,
#     'duration': 5.699,
#     'transcript_text': 'in the middle see how it frames out this'},
#    {'start_time': 643.08,
#     'duration': 6.18,
#     'transcript_text': 'section more yeah and even like'},
#    {'start_time': 645.959,
#     'duration': 6.921,
#     'transcript_text': 'swagging back yeah'},
#    {'start_time': 649.26,
#     'duration': 3.62,
#     'transcript_text': "chef's kiss real fancy"},
#    {'start_time': 655.399,
#     'duration': 5.261,
#     'transcript_text': "for my final project it's not one big"},
#    {'start_time': 658.32,
#     'duration': 4.5,
#     'transcript_text': "project it's a bunch of little projects"},
#    {'start_time': 660.66,
#     'duration': 4.32,
#     'transcript_text': "I went to Lowe's picked out a ton of"},
#    {'start_time': 662.82,
#     'duration': 4.8,
#     'transcript_text': "items that I loved and then I'm doing"},
#    {'start_time': 664.98,
#     'duration': 5.52,
#     'transcript_text': 'small little DIY projects to customize'},
#    {'start_time': 667.62,
#     'duration': 4.26,
#     'transcript_text': 'them I found these awesome nightstands'},
#    {'start_time': 670.5,
#     'duration': 3.3,
#     'transcript_text': 'that I loved because they were a little'},
#    {'start_time': 671.88,
#     'duration': 3.66,
#     'transcript_text': 'bit bigger and they have a really'},
#    {'start_time': 673.8,
#     'duration': 4.26,
#     'transcript_text': 'beautiful vintage style they came with'},
#    {'start_time': 675.54,
#     'duration': 4.979,
#     'transcript_text': 'this awesome Hardware but they were a'},
#    {'start_time': 678.06,
#     'duration': 4.56,
#     'transcript_text': 'really stark white color so that can'},
#    {'start_time': 680.519,
#     'duration': 4.741,
#     'transcript_text': 'easily be fixed a little pink'},
#    {'start_time': 682.62,
#     'duration': 4.98,
#     'transcript_text': 'I primed them and then painted them this'},
#    {'start_time': 685.26,
#     'duration': 4.259,
#     'transcript_text': 'Rich kind of Golden Rod yellow that just'},
#    {'start_time': 687.6,
#     'duration': 4.38,
#     'transcript_text': 'really pops against all the blue tones'},
#    {'start_time': 689.519,
#     'duration': 4.081,
#     'transcript_text': 'in here I chose to leave the wood top'},
#    {'start_time': 691.98,
#     'duration': 3.599,
#     'transcript_text': 'the same so that there was a little bit'},
#    {'start_time': 693.6,
#     'duration': 3.179,
#     'transcript_text': 'more of a layering and a contrast in'},
#    {'start_time': 695.579, 'duration': 3.361, 'transcript_text': 'there'},
#    {'start_time': 696.779,
#     'duration': 3.601,
#     'transcript_text': "I found these lamps but I thought we'd"},
#    {'start_time': 698.94,
#     'duration': 3.42,
#     'transcript_text': 'change up the color with a little bit of'},
#    {'start_time': 700.38,
#     'duration': 5.04,
#     'transcript_text': 'spray paint spray painted them this Rich'},
#    {'start_time': 702.36,
#     'duration': 5.159,
#     'transcript_text': 'orange and then for the shade took some'},
#    {'start_time': 705.42,
#     'duration': 4.32,
#     'transcript_text': 'fabric trimming and hot glued it around'},
#    {'start_time': 707.519,
#     'duration': 5.301,
#     'transcript_text': 'the edge completely changes the look and'},
#    {'start_time': 709.74,
#     'duration': 3.08,
#     'transcript_text': 'makes it perfect for this space'},
#    {'start_time': 714.68, 'duration': 4.839, 'transcript_text': 'foreign'},
#    {'start_time': 717.2,
#     'duration': 3.819,
#     'transcript_text': 'Dan helped me hang the curtains in the'},
#    {'start_time': 719.519,
#     'duration': 4.141,
#     'transcript_text': "rod but what he didn't know is that it"},
#    {'start_time': 721.019,
#     'duration': 6.181,
#     'transcript_text': 'had one more customization that I had in'},
#    {'start_time': 723.66,
#     'duration': 6.359,
#     'transcript_text': 'mind I found on lowes.com this amazing'},
#    {'start_time': 727.2,
#     'duration': 6.0,
#     'transcript_text': 'wallpaper I decided that I would create'},
#    {'start_time': 730.019,
#     'duration': 5.401,
#     'transcript_text': 'a 1x8 board that almost acts as a'},
#    {'start_time': 733.2,
#     'duration': 4.98,
#     'transcript_text': 'cornice going across here to cover our'},
#    {'start_time': 735.42,
#     'duration': 4.32,
#     'transcript_text': 'Rod it really visually draws your eye as'},
#    {'start_time': 738.18,
#     'duration': 3.96,
#     'transcript_text': 'soon as you walk into the room and again'},
#    {'start_time': 739.74,
#     'duration': 5.039,
#     'transcript_text': 'drawing the eye up and really creating'},
#    {'start_time': 742.14,
#     'duration': 4.62,
#     'transcript_text': 'this Nook here as something special the'},
#    {'start_time': 744.779,
#     'duration': 3.721,
#     'transcript_text': 'radiators in this space were one of the'},
#    {'start_time': 746.76,
#     'duration': 3.66,
#     'transcript_text': 'amazing features that it already had'},
#    {'start_time': 748.5,
#     'duration': 5.16,
#     'transcript_text': 'going for it and I wanted to draw more'},
#    {'start_time': 750.42,
#     'duration': 5.4,
#     'transcript_text': 'attention to them so I painted them a'},
#    {'start_time': 753.66,
#     'duration': 3.96,
#     'transcript_text': 'couple Shades Darker than my wall color'},
#    {'start_time': 755.82,
#     'duration': 3.959,
#     'transcript_text': "it's really going to make it more of a"},
#    {'start_time': 757.62,
#     'duration': 4.08,
#     'transcript_text': 'feature now if you have an old radiator'},
#    {'start_time': 759.779,
#     'duration': 3.961,
#     'transcript_text': "you can paint them and you don't even"},
#    {'start_time': 761.7,
#     'duration': 3.84,
#     'transcript_text': "need a specialty paint they don't get so"},
#    {'start_time': 763.74,
#     'duration': 3.839,
#     'transcript_text': "hot that they'll melt paint so it's safe"},
#    {'start_time': 765.54,
#     'duration': 4.919,
#     'transcript_text': 'to do it I mean make it a focal point'},
#    {'start_time': 767.579,
#     'duration': 4.56,
#     'transcript_text': "it's such a unique character driven item"},
#    {'start_time': 770.459,
#     'duration': 3.781,
#     'transcript_text': "that new homes today don't have"},
#    {'start_time': 772.139,
#     'duration': 3.661,
#     'transcript_text': 'switching out the hardware on a piece of'},
#    {'start_time': 774.24,
#     'duration': 3.719,
#     'transcript_text': 'furniture is one of the simplest things'},
#    {'start_time': 775.8,
#     'duration': 4.26,
#     'transcript_text': 'you can do to make it more customized so'},
#    {'start_time': 777.959,
#     'duration': 3.841,
#     'transcript_text': 'this was the original Hardware totally'},
#    {'start_time': 780.06,
#     'duration': 2.94,
#     'transcript_text': 'fine would have worked in this room but'},
#    {'start_time': 781.8,
#     'duration': 3.539,
#     'transcript_text': 'when I was walking through the hardware'},
#    {'start_time': 783.0,
#     'duration': 4.079,
#     'transcript_text': "section at Lowe's these guys caught my"},
#    {'start_time': 785.339,
#     'duration': 3.361,
#     'transcript_text': "eye but of course we didn't just keep"},
#    {'start_time': 787.079,
#     'duration': 3.421,
#     'transcript_text': 'them white and now it has a nice'},
#    {'start_time': 788.7,
#     'duration': 4.699,
#     'transcript_text': 'contrast from the new fabric I think'},
#    {'start_time': 790.5,
#     'duration': 2.899,
#     'transcript_text': "it's perfect for this space"},
#    {'start_time': 797.54,
#     'duration': 4.78,
#     'transcript_text': 'all right guys this has been so fun for'},
#    {'start_time': 800.459,
#     'duration': 3.301,
#     'transcript_text': 'me to work in this such a cool house'},
#    {'start_time': 802.32,
#     'duration': 3.98,
#     'transcript_text': 'this weekend so on the count of three'},
#    {'start_time': 803.76,
#     'duration': 6.139,
#     'transcript_text': 'one two three'},
#    {'start_time': 806.3, 'duration': 3.599, 'transcript_text': 'oh my god oh'},
#    {'start_time': 811.2, 'duration': 2.66, 'transcript_text': 'different'},
#    {'start_time': 816.38, 'duration': 5.44, 'transcript_text': 'oh my God'},
#    {'start_time': 819.24,
#     'duration': 4.92,
#     'transcript_text': 'this is crazy'},
#    {'start_time': 821.82,
#     'duration': 3.9,
#     'transcript_text': 'having the bed against this wall and'},
#    {'start_time': 824.16,
#     'duration': 2.88,
#     'transcript_text': 'having the space that otherwise was'},
#    {'start_time': 825.72,
#     'duration': 3.239,
#     'transcript_text': "behind the headboard and that we didn't"},
#    {'start_time': 827.04,
#     'duration': 5.039,
#     'transcript_text': 'really use but as like a nice little'},
#    {'start_time': 828.959,
#     'duration': 5.521,
#     'transcript_text': 'sitting area is so cozy and sweet I love'},
#    {'start_time': 832.079,
#     'duration': 5.041,
#     'transcript_text': "that it's like a hangout space now the"},
#    {'start_time': 834.48,
#     'duration': 5.099,
#     'transcript_text': 'wallpapering in the panels is such a'},
#    {'start_time': 837.12,
#     'duration': 3.959,
#     'transcript_text': 'nice touch I love that even like all the'},
#    {'start_time': 839.579,
#     'duration': 3.301,
#     'transcript_text': "mix and stuff so I'm like The Gingham on"},
#    {'start_time': 841.079,
#     'duration': 3.06,
#     'transcript_text': 'the bed but it ties in over here and'},
#    {'start_time': 842.88,
#     'duration': 3.18,
#     'transcript_text': "there's like a lot of different patterns"},
#    {'start_time': 844.139,
#     'duration': 5.7,
#     'transcript_text': 'without them like clashing this looks'},
#    {'start_time': 846.06,
#     'duration': 5.459,
#     'transcript_text': "nice and big yeah like it's great it has"},
#    {'start_time': 849.839,
#     'duration': 3.781,
#     'transcript_text': 'a lot of storage in there now and I do'},
#    {'start_time': 851.519,
#     'duration': 3.601,
#     'transcript_text': 'think layout wise that was one of the'},
#    {'start_time': 853.62,
#     'duration': 4.019,
#     'transcript_text': 'biggest things hindering this room like'},
#    {'start_time': 855.12,
#     'duration': 4.68,
#     'transcript_text': 'we were blocking that amazing feature'},
#    {'start_time': 857.639,
#     'duration': 4.561,
#     'transcript_text': 'the bay window and now I just feel like'},
#    {'start_time': 859.8,
#     'duration': 4.08,
#     'transcript_text': 'even the flow in here just feels it'},
#    {'start_time': 862.2,
#     'duration': 3.48,
#     'transcript_text': 'feels bigger to me'},
#    {'start_time': 863.88,
#     'duration': 4.44,
#     'transcript_text': 'pain of the radiator painted the'},
#    {'start_time': 865.68,
#     'duration': 4.86,
#     'transcript_text': 'radiator Blends in lovely the'},
#    {'start_time': 868.32,
#     'duration': 4.38,
#     'transcript_text': 'nightstands are great the yellow is also'},
#    {'start_time': 870.54,
#     'duration': 3.84,
#     'transcript_text': 'something that I would never have picked'},
#    {'start_time': 872.7,
#     'duration': 3.96,
#     'transcript_text': 'I think it works so well with the other'},
#    {'start_time': 874.38,
#     'duration': 3.48,
#     'transcript_text': 'colors so like my final project was a'},
#    {'start_time': 876.66,
#     'duration': 3.0,
#     'transcript_text': 'lot of small projects that were'},
#    {'start_time': 877.86,
#     'duration': 3.479,
#     'transcript_text': 'customizing like we did everything the'},
#    {'start_time': 879.66,
#     'duration': 3.84,
#     'transcript_text': 'ceiling to trim the walls all the same'},
#    {'start_time': 881.339,
#     'duration': 3.961,
#     'transcript_text': 'color but then we needed to add the'},
#    {'start_time': 883.5,
#     'duration': 2.94,
#     'transcript_text': 'personality and add the vibrancy that'},
#    {'start_time': 885.3,
#     'duration': 3.36,
#     'transcript_text': 'you have throughout the rest of your'},
#    {'start_time': 886.44,
#     'duration': 4.259,
#     'transcript_text': 'home there are so many patterns and so'},
#    {'start_time': 888.66,
#     'duration': 4.2,
#     'transcript_text': 'many textures but they all kind of work'},
#    {'start_time': 890.699,
#     'duration': 3.781,
#     'transcript_text': 'together yeah this balance all the way'},
#    {'start_time': 892.86,
#     'duration': 3.659,
#     'transcript_text': 'across that has the same wallpaper over'},
#    {'start_time': 894.48,
#     'duration': 3.06,
#     'transcript_text': 'here she did so many little projects'},
#    {'start_time': 896.519, 'duration': 3.421, 'transcript_text': 'Monica'},
#    {'start_time': 897.54,
#     'duration': 4.2,
#     'transcript_text': 'that is really my favorite part because'},
#    {'start_time': 899.94,
#     'duration': 3.3,
#     'transcript_text': 'taking what everybody can have making'},
#    {'start_time': 901.74,
#     'duration': 3.18,
#     'transcript_text': 'small little changes to make it just'},
#    {'start_time': 903.24,
#     'duration': 3.539,
#     'transcript_text': 'right for you guys and hopefully you'},
#    {'start_time': 904.92,
#     'duration': 3.9,
#     'transcript_text': 'feel like this is a place you now want'},
#    {'start_time': 906.779,
#     'duration': 3.481,
#     'transcript_text': 'to come to you want to spend time in I'},
#    {'start_time': 908.82,
#     'duration': 2.819,
#     'transcript_text': 'think it is I think you nailed it I'},
#    {'start_time': 910.26,
#     'duration': 3.91,
#     'transcript_text': "think it's great we really really like"},
#    {'start_time': 911.639,
#     'duration': 4.44,
#     'transcript_text': "it I'm so glad I'm so so glad"},
#    {'start_time': 914.17, 'duration': 3.71, 'transcript_text': '[Music]'},
#    {'start_time': 916.079,
#     'duration': 4.2,
#     'transcript_text': "okay that's a wrap on another Lowe's"},
#    {'start_time': 917.88,
#     'duration': 4.259,
#     'transcript_text': 'Weekender makeover I know the style of'},
#    {'start_time': 920.279,
#     'duration': 3.661,
#     'transcript_text': "this bedroom isn't everybody's style but"},
#    {'start_time': 922.139,
#     'duration': 3.361,
#     'transcript_text': 'I would still love for you to leave me a'},
#    {'start_time': 923.94,
#     'duration': 4.079,
#     'transcript_text': 'comment below let me know what your'},
#    {'start_time': 925.5,
#     'duration': 4.62,
#     'transcript_text': 'favorite part of this makeover was and'},
#    {'start_time': 928.019,
#     'duration': 4.26,
#     'transcript_text': 'as always all of the things believe it'},
#    {'start_time': 930.12,
#     'duration': 3.959,
#     'transcript_text': 'or not that you see in this face are'},
#    {'start_time': 932.279,
#     'duration': 3.601,
#     'transcript_text': "from Lowe's and we'll put all the links"},
#    {'start_time': 934.079,
#     'duration': 3.12,
#     'transcript_text': 'in the description below and before you'},
#    {'start_time': 935.88,
#     'duration': 2.639,
#     'transcript_text': 'go make sure you hit that subscribe'},
#    {'start_time': 937.199,
#     'duration': 2.941,
#     'transcript_text': "button you don't want to miss a single"},
#    {'start_time': 938.519,
#     'duration': 7.251,
#     'transcript_text': 'thing thanks friends'},
#    {'start_time': 940.14, 'duration': 5.63, 'transcript_text': '[Music]'}]}}

# %%
VIDEO_ID = 'cdY-4gH5H-Q'
# Print the resulting dictionary
print(video_info[VIDEO_ID])
# Out:
# {'video_title': 'How To Cut Tile #diy #kitchenremodel #howtotile', 'video_transcript': [{'start_time': 0.88, 'duration': 3.64, 'transcript_text': 'build your DIY confidence and learn how'}, {'start_time': 2.679, 'duration': 4.321, 'transcript_text': 'to cut'}, {'start_time': 4.52, 'duration': 3.8, 'transcript_text': "tiles if you're tiling a floor or wall"}, {'start_time': 7.0, 'duration': 4.36, 'transcript_text': "you'll probably need to cut some tiles"}, {'start_time': 8.32, 'duration': 5.279, 'transcript_text': 'to fit the space and a wet tile saw is'}, {'start_time': 11.36, 'duration': 4.12, 'transcript_text': 'perfect for the job it uses the water to'}, {'start_time': 13.599, 'duration': 4.081, 'transcript_text': "cool down the tile as it's being cut so"}, {'start_time': 15.48, 'duration': 4.84, 'transcript_text': "it doesn't break don't worry if you've"}, {'start_time': 17.68, 'duration': 4.2, 'transcript_text': "never used one before it's safe and easy"}, {'start_time': 20.32, 'duration': 3.48, 'transcript_text': 'line up your mark cut and push your tile'}, {'start_time': 21.88, 'duration': 5.2, 'transcript_text': 'forward slow and'}, {'start_time': 23.8, 'duration': 3.28, 'transcript_text': 'steady nice'}, {'start_time': 28.48, 'duration': 3.0, 'transcript_text': 'work'}]}

# %%
# Download the youtube video to local
#download_path = '/Users/runzhou/Desktop/rag/data'
download_path = '/Users/danielcohen/Desktop/RAG/data'

#made this a for loop to make choosing specific videos easier
VIDEO_IDS = ['9EFo6EKtYUo',  '9tvPeP6O-6M', 'BPhdUVH7NzE','CPey-f0HP4o','CfDwDFkmVQQ'] #Video id #11- 15
for VIDEO_ID in VIDEO_IDS:
    video_url = f'https://www.youtube.com/watch?v=' + VIDEO_ID
    yt = YouTube(video_url)
    stream = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
    if stream:
        # Download the video and get the file path
        file_path = stream.download(download_path)
        print(f'Downloaded: {yt.title}')
        print(f'File path: {file_path}')
    else:
        print(f'Could not download: {yt.title}')
# Out:
# Downloaded: Junk Drawer No More
# File path: /Users/danielcohen/Desktop/RAG/data/Junk Drawer No More.mp4
# Downloaded: Power Outage? Never Heard Of It.
# File path: /Users/danielcohen/Desktop/RAG/data/Power Outage Never Heard Of It.mp4
# Downloaded: How to Replace Faucets and Fix Drainage Issues | DIY-U by Lowe's
# File path: /Users/danielcohen/Desktop/RAG/data/How to Replace Faucets and Fix Drainage Issues  DIY-U by Lowes.mp4
# Downloaded: Deck Your Hallway With This Holiday Hack
# File path: /Users/danielcohen/Desktop/RAG/data/Deck Your Hallway With This Holiday Hack.mp4
# Downloaded: How to Sharpen, Balance and Change Lawn Mower Blades | How To Anything
# File path: /Users/danielcohen/Desktop/RAG/data/How to Sharpen Balance and Change Lawn Mower Blades  How To Anything.mp4

# %% [markdown]
# #### After downloading data, now analyze each frame:

# %%
#!pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/danielcohen/miniconda3/lib/python3.11/site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 8.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80

# %%
# Get frames of a given video
import cv2
# Read the video from specified path
file_path = '/Users/danielcohen/Desktop/rag/data/".mp4'
cam = cv2.VideoCapture(file_path)

# frame
currentframe = 0
while True:
    # reading from frame
    ret, frame = cam.read()
    if ret:
        # if video is still left continue creating images
        #name = '/Users/runzhou/Desktop/rag/data/video_frame/frame_' + str(currentframe) + '.jpg'
        name = '/Users/danielcohen/Desktop/RAG/data/video_frame/frame_' + str(currentframe) + '.jpg'
        print ('Creating...' + name)
        # writing the extracted images
        cv2.imwrite(name, frame)
        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
    else:
        break
# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()
# Out:
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame
jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_370.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_371.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_372.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_373.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_374.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_375.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_376.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_377.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_378.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_379.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_380.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_381.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_382.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_383.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_384.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_385.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_386.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_387.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_388.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_389.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_390.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_391.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_392.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_393.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_394.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_395.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_396.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_397.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_398.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_399.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_400.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_401.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_402.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_403.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_404.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_405.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_406.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_407.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_408.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_409.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_410.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_411.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_412.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_413.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_414.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_415.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_416.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_417.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_418.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_419.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_420.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_421.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_422.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_423.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_424.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_425.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_426.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_427.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_428.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_429.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_430.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_431.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_432.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_433.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_434.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_435.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_436.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_437.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_438.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_439.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_440.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_441.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_442.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_443.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_444.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_445.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_446.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_447.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_448.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_449.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_450.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_451.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_452.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_453.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_454.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_455.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_456.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_457.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_458.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_459.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_460.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_461.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_462.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_463.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_464.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_465.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_466.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_467.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_468.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_469.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_470.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_471.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_472.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_473.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_474.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_475.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_476.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_477.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_478.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_479.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_480.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_481.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_482.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_483.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_484.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_485.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_486.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_487.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_488.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_489.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_490.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_491.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_492.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_493.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_494.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_495.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_496.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_497.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_498.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_499.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_500.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_501.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_502.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_503.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_504.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_505.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_506.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_507.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_508.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_509.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_510.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_511.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_512.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_513.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_514.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_515.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_516.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_517.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_518.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_519.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_520.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_521.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_522.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_523.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_524.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_525.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_526.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_527.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_528.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_529.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_530.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_531.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_532.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_533.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_534.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_535.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_536.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_537.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_538.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_539.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_540.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_541.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_542.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_543.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_544.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_545.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_546.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_547.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_548.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_549.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_550.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_551.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_552.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_553.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_554.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_555.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_556.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_557.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_558.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_559.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_560.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_561.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_562.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_563.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_564.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_565.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_566.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_567.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_568.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_569.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_570.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_571.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_572.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_573.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_574.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_575.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_576.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_577.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_578.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_579.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_580.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_581.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_582.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_583.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_584.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_585.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_586.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_587.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_588.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_589.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_590.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_591.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_592.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_593.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_594.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_595.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame/frame_596.jpg

# %%
# get all start time in the video_info
VIDEO_ID = VIDEO_IDS[0]
start_times = [item['start_time'] for item in video_info[VIDEO_ID]['video_transcript']]
print(start_times)
# Out:
# [0.199, 1.76, 4.16, 5.96, 7.56, 9.28, 10.8, 12.2, 14.759, 16.16, 18.92]

# %%
import os
# Get the captured frame corresponding to the segment start times
# Read the video from specified path
cam = cv2.VideoCapture(file_path)

#Set the directory path for video frame start times
#directory = '/Users/runzhou/Desktop/rag/data/video_frame_starttime'
directory = '/Users/danielcohen/Desktop/RAG/data/video_frame_starttime'

# Check if the directory exists
if not os.path.exists(directory):
    # Create the directory
    os.makedirs(directory)
    print(f'Directory created: {directory}')
else:
    print(f'Directory already exists: {directory}')

# FPS
fps = cam.get(cv2.CAP_PROP_FPS)
captured_frames = []
for target_time in start_times:
    # set the frame point to capture from
    cam.set(cv2.CAP_PROP_POS_MSEC, target_time * 1000)

    # read the frame
    ret, frame = cam.read()

    # save the captured frame
    if ret:
        #name = '/Users/runzhou/Desktop/rag/data/video_frame_starttime/frame_at_' + str(target_time) + '.jpg'
        name = '/Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_' + str(target_time) + '.jpg'
        captured_frames.append(name)
        print ('Creating...' + name)
        # writing the extracted images
        cv2.imwrite(name, frame)
    else:
        print("Error: Failed to read frame at {} seconds.".format(target_time))

# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()
# Out:
# Directory already exists: /Users/danielcohen/Desktop/RAG/data/video_frame_starttime
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_0.199.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_1.76.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_4.16.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_5.96.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_7.56.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_9.28.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_10.8.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_12.2.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_14.759.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_16.16.jpg
# Creating.../Users/danielcohen/Desktop/RAG/data/video_frame_starttime/frame_at_18.92.jpg

# %% [markdown]
# ## Eden AI

# %%
# Detect objects in the captured frames
import json
import requests

object_detected_amazon = []
object_detected_google = []

for frame in captured_frames:
    # if frame.split('/')[-1] == "frame_at_9.28.jpg":
    headers = {"Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYjVkMTM0MmMtYTAzNC00ZmNhLTg4NmEtOGNhYzk2YmYxYjA2IiwidHlwZSI6ImFwaV90b2tlbiJ9.AI0apCBMmPPLg9Vo4BftZ7PCr3YCgyG1KIk2EDxTNV0"}

    url = "https://api.edenai.run/v2/image/object_detection"
    data = {
        "providers": "google,amazon",
        "fallback_providers": ""
    }
    files = {'file': open(frame, 'rb')}

    response = requests.post(url, data=data, files=files, headers=headers)
    result = json.loads(response.text)
    print("Items detected in " + frame.split('/')[-1] + ":")
    if 'amazon' in result and 'items' in result['amazon']:
        object_list = [item['label'] for item in result['amazon']['items']]
        object_detected_amazon.append(object_list)
        print("Amazon response:")
        print(object_list)
    else:
        object_detected_amazon.append([])
    if 'google' in result and 'items' in result['google']:
        object_list = [item['label'] for item in result['google']['items']]
        object_detected_google.append(object_list)
        print("Google response:")
        print(object_list)
    else:
        object_detected_google.append([])
# Out:
# Items detected in frame_at_0.199.jpg:
# Amazon response:
# ['Drawer', 'Furniture', 'Cabinet', 'Business Card', 'Paper', 'Text', 'Dynamite', 'Weapon']
# Google response:
# []
# Items detected in frame_at_1.76.jpg:
# Amazon response:
# ['Drawer', 'Furniture', 'Cabinet', 'Business Card', 'Paper', 'Text', 'Can', 'Tin', 'Box']
# Google response:
# []
# Items detected in frame_at_4.16.jpg:
# Amazon response:
# ['Drawer', 'Furniture', 'Cabinet', 'Box', 'First Aid']
# Google response:
# []
# Items detected in frame_at_5.96.jpg:
# Amazon response:
# ['Indoors', 'Interior Design', 'Boy', 'Child', 'Male', 'Person', 'Photo Frame', 'Window', 'Windowsill', 'Business Card', 'Paper', 'Text']
# Google response:
# []
# Items detected in frame_at_7.56.jpg:
# Amazon response:
# ['Advertisement', 'Poster', 'Business Card', 'Paper', 'Text']
# Google response:
# []
# Items detected in frame_at_9.28.jpg:
# Items detected in frame_at_10.8.jpg:
# Items detected in frame_at_12.2.jpg:
# Items detected in frame_at_14.759.jpg:
# Items detected in frame_at_16.16.jpg:
# Items detected in frame_at_18.92.jpg:

# %%
# Print object detected by Amazon API
object_detected_amazon
# Out:
# [['Drawer',
#   'Furniture',
#   'Cabinet',
#   'Business Card',
#   'Paper',
#   'Text',
#   'Dynamite',
#   'Weapon'],
#  ['Drawer',
#   'Furniture',
#   'Cabinet',
#   'Business Card',
#   'Paper',
#   'Text',
#   'Can',
#   'Tin',
#   'Box'],
#  ['Drawer', 'Furniture', 'Cabinet', 'Box', 'First Aid'],
#  ['Indoors',
#   'Interior Design',
#   'Boy',
#   'Child',
#   'Male',
#   'Person',
#   'Photo Frame',
#   'Window',
#   'Windowsill',
#   'Business Card',
#   'Paper',
#   'Text'],
#  ['Advertisement', 'Poster', 'Business Card', 'Paper', 'Text'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
# Print object detected by Google API
object_detected_google
# Out:
# [['Glasses', 'Clothing', 'Person'],
#  [],
#  [],
#  ['Person', 'Clothing', 'Shoe', 'Footwear', 'Person'],
#  ['Shoe', 'Boot', 'Footwear'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
frame = "/Users/runzhou/Desktop/rag/data/video_frame_starttime/frame_at_7.0.jpg"

# if frame.split('/')[-1] == "frame_at_9.28.jpg":
headers = {"Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYjVkMTM0MmMtYTAzNC00ZmNhLTg4NmEtOGNhYzk2YmYxYjA2IiwidHlwZSI6ImFwaV90b2tlbiJ9.AI0apCBMmPPLg9Vo4BftZ7PCr3YCgyG1KIk2EDxTNV0"}

url = "https://api.edenai.run/v2/image/object_detection"
data = {
    "providers": "google,amazon",
    "fallback_providers": ""
}
files = {'file': open(frame, 'rb')}

response = requests.post(url, data=data, files=files, headers=headers)
result = json.loads(response.text)
print("Items detected in " + frame.split('/')[-1] + ":")
if 'amazon' in result and 'items' in result['amazon']:
    object_list = [item['label'] for item in result['amazon']['items']]
    print("Amazon response:")
    print(object_list)
if 'google' in result and 'items' in result['google']:
    object_list = [item['label'] for item in result['google']['items']]
    print("Google response:")
    print(object_list)
# Out:
# Items detected in frame_at_7.0.jpg:
# Amazon response:
# ['Floor', 'Flooring', 'Indoors', 'Interior Design', 'Person', 'Face', 'Head', 'Home Renovation Work']
# Google response:
# ['Person', 'Clothing', 'Shoe', 'Footwear', 'Person']

# %% [markdown]
# #### ************* Summary *************
# ##### 1. Process videos to create a pandas dataframe with the following info:
# #####           video ID, segment start time, segment-level transcript, list of objects detected
# ##### 2. Create embeddings for segment-level transcripts and the list of objects detected
# ##### 3. Ingest the embeddings into ChromaDB
# #### ************************************

# %%
#!pip install spacy
#!python -m spacy download en_core_web_sm

# %%
print("We are about to process {x} videos".format(x=len(video_info)))
# Out:
# We are about to process 99 videos

# %%
import cv2
import pandas as pd
import os
import json
import requests
import spacy
import re
import shutil
from pytube import YouTube

# Load the language model
nlp = spacy.load("en_core_web_sm")


def clear_directory(directory):
    # Check if the directory exists
    if os.path.exists(directory):
        # Remove all files in the directory
        shutil.rmtree(directory)
        print(f"Cleared directory: {directory}")
    # Recreate the directory
    os.makedirs(directory)

def download_video(video_id, download_path):
    video_url = f'https://www.youtube.com/watch?v=' + video_id
    yt = YouTube(video_url)
    stream = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
    if stream:
        file_path = stream.download(download_path)
        print(f'Downloaded: {yt.title}')
        print(f'File path: {file_path}')
        return file_path
    else:
        print(f'Could not download: {yt.title}')
        return None

def get_captured_frames(file_path, start_times, directory):
    cam = cv2.VideoCapture(file_path)
    captured_frames = []
    for target_time in start_times:
        cam.set(cv2.CAP_PROP_POS_MSEC, target_time * 1000)
        ret, frame = cam.read()
        if ret:
            name = os.path.join(directory, f'frame_at_{target_time}.jpg')
            captured_frames.append(name)
            cv2.imwrite(name, frame)
        else:
            print(f"Error: Failed to read frame at {target_time} seconds.")
    cam.release()
    cv2.destroyAllWindows()
    return captured_frames

def detect_objects(captured_frames, provider, token):
    object_detected = []
    headers = {"Authorization": "Bearer {x}".format(x=token)}
    url = "https://api.edenai.run/v2/image/object_detection"
    data = {
        "providers": provider,
        "fallback_providers": ""
    }
    for frame in captured_frames:
        files = {'file': open(frame, 'rb')}
        response = requests.post(url, data=data, files=files, headers=headers)
        result = json.loads(response.text)
        if provider in result and 'items' in result[provider]:
            object_list = [item['label'] for item in result[provider]['items']]
            object_detected.append(object_list)
        else:
            object_detected.append([])
    return object_detected

# Function to check if a sentence contains a keyword
def contains_keyword(sent, keywords):
    for token in sent:
        if token.lemma_.lower() in keywords:
            return True
    return False

# Function to check if a sentence is imperative
def is_imperative(sent):
    first_token = sent[0]
    if first_token.pos_ == "VERB" and first_token.lemma_ == first_token.text and first_token.text.lower() not in ["is", "are", "was", "were"]:
        return True
    return False

# Function to check the segmented transcript and return relevant sentences with start times
def check_segmented_transcript(segmented_transcript, nlp_model, top_n):
    # List of keywords that indicate steps or imperatives
    step_keywords = ["step", "first", "next", "then", "now", "lastly", "finally", "secondly", "thirdly"]

    relevant_segments = []
    for segment in segmented_transcript:
        doc = nlp_model(segment['transcript_text'])
        for sent in doc.sents:
            if contains_keyword(sent, step_keywords) or is_imperative(sent):
                relevant_segments.append({'start_time': segment['start_time'], 'transcript_text': sent.text})
    # Sort the relevant segments based on your criteria for relevance
    # For simplicity, this example just takes the first N relevant segments
    # You can modify this to sort based on a more sophisticated relevance metric
    relevant_segments = relevant_segments[:top_n]
    return relevant_segments

# Function to combine transcripts and keep track of start times
def combine_transcripts_with_timing(transcript_data):
    combined_transcript = ""
    segment_start_times = []
    current_start_time = 0.000

    for segment in transcript_data:
        # Append the transcript text to the combined transcript
        combined_transcript += segment['transcript_text'] + " "

        # Record the start time for this segment
        segment_start_times.append(current_start_time)

        # Update the current start time for the next segment
        current_start_time += segment['start_time']

    # Remove the trailing space from the combined transcript
    combined_transcript = combined_transcript.strip()

    return combined_transcript, segment_start_times

def segment_transcript_with_timing(combined_transcript, segment_start_times, nlp_model):
    segmented_transcript = []
    doc = nlp_model(combined_transcript)

    # Initialize variables to keep track of the current segment and word count
    current_segment_index = 0
    current_word_count = 0

    for sent in doc.sents:
        sentence_word_count = len(sent.text.split())

        # Update the segment index if the current sentence goes beyond the current segment
        while (current_segment_index < len(segment_start_times) - 1 and
               current_word_count + sentence_word_count > len(combined_transcript[:combined_transcript.find(segmented_transcript[current_segment_index + 1]['transcript_text']) if current_segment_index + 1 < len(segmented_transcript) else len(combined_transcript)].split())):
            current_segment_index += 1

        # Add the sentence and its start time to the segmented transcript
        segmented_transcript.append({'start_time': segment_start_times[current_segment_index], 'transcript_text': sent.text})

        # Update the word count for the next sentence
        current_word_count += sentence_word_count

    return segmented_transcript


def process_videos(video_info, object_detection_api_token):
    # Set path for video download
    download_path = '/Users/runzhou/Desktop/rag/data'
    directory = '/Users/runzhou/Desktop/rag/data/video_frame_starttime'
    
    # Initialize an empty DataFrame
    df = pd.DataFrame()

    for video_id, info in video_info.items():
        # Clear the directory for captured frames
        clear_directory(directory)

        file_path = download_video(video_id, download_path)
        print("Processing file: {x}".format(x=file_path))
        if file_path:
            # Combine the transcript segments and keep track of start times
            combined_transcript, segment_start_times = combine_transcripts_with_timing(info['video_transcript'])

            # Segment the combined transcript and assign start times
            segmented_transcript = segment_transcript_with_timing(combined_transcript, segment_start_times, nlp)

            # Preprocess the transcript to get the most relevant sentences
            relevant_segments = check_segmented_transcript(segmented_transcript, nlp, top_n=5)
            #print(relevant_segments)

            # Get captured frames for the start times of the relevant segments
            start_times = [seg['start_time'] for seg in relevant_segments]
            captured_frames = get_captured_frames(file_path, start_times, directory)
            print("{x} captured frames.".format(x=len(captured_frames)))

            # Detect objects in the captured frames using Amazon Rekognition
            object_detected_amazon = detect_objects(captured_frames, 'amazon', object_detection_api_token)
            print(f"Object detection completed for {len(object_detected_amazon)} frames.")


            # Append processed rows to the DataFrame
            for i, segment in enumerate(relevant_segments):
                row = {
                    'video_id': video_id,
                    'segment_start_time': segment['start_time'],
                    'segmented_transcript': segment['transcript_text'],
                    'captured_frame_path': captured_frames[i] if i < len(captured_frames) else None,
                    'objects_detected_amazon': object_detected_amazon[i] if i < len(object_detected_amazon) else None
                }
                df = df.append(row, ignore_ind=True)
        
        return df


#video_info_sample = video_info.get('nHMFNj3i5j0')

object_detection_api_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYjVkMTM0MmMtYTAzNC00ZmNhLTg4NmEtOGNhYzk2YmYxYjA2IiwidHlwZSI6ImFwaV90b2tlbiJ9.AI0apCBMmPPLg9Vo4BftZ7PCr3YCgyG1KIk2EDxTNV0'
df = process_videos(video_info, object_detection_api_token)
print(df)
# Out:
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How To Paint Cabinets | A Step-by-Step Guide
# File path: /Users/runzhou/Desktop/rag/data/How To Paint Cabinets  A Step-by-Step Guide.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How To Paint Cabinets  A Step-by-Step Guide.mp4
# 5 captured frames.
# Object detection completed for 5 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: An oh-so-satisfying steam clean 😌
# File path: /Users/runzhou/Desktop/rag/data/An oh-so-satisfying steam clean 😌.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/An oh-so-satisfying steam clean 😌.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How To Cut Tile #diy #kitchenremodel #howtotile
# File path: /Users/runzhou/Desktop/rag/data/How To Cut Tile diy kitchenremodel howtotile.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How To Cut Tile diy kitchenremodel howtotile.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How To Tile a Backsplash | A Step-by-Step Guide
# File path: /Users/runzhou/Desktop/rag/data/How To Tile a Backsplash  A Step-by-Step Guide.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How To Tile a Backsplash  A Step-by-Step Guide.mp4
# 5 captured frames.
# Object detection completed for 5 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Your Plunger Is Disgusting 🪠🤢
# File path: /Users/runzhou/Desktop/rag/data/Your Plunger Is Disgusting 🪠🤢.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Your Plunger Is Disgusting 🪠🤢.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How To Place Tile #diy #kitchenremodel #howtotile
# File path: /Users/runzhou/Desktop/rag/data/How To Place Tile diy kitchenremodel howtotile.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How
How To Anything.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Install a Smart Lock and Deadbolt  How To Anything.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Say Goodbye to Unruly Rolls of Wrapping Paper
# File path: /Users/runzhou/Desktop/rag/data/Say Goodbye to Unruly Rolls of Wrapping Paper.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Say Goodbye to Unruly Rolls of Wrapping Paper.mp4
# 0 captured frames.
# Object detection completed for 0 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Deck Your Hallway With This Holiday Hack
# File path: /Users/runzhou/Desktop/rag/data/Deck Your Hallway With This Holiday Hack.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Deck Your Hallway With This Holiday Hack.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How to Install a Smart Thermostat | How To Anything
# File path: /Users/runzhou/Desktop/rag/data/How to Install a Smart Thermostat  How To Anything.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Install a Smart Thermostat  How To Anything.mp4
# 2 captured frames.
# Object detection completed for 2 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Lights For All The Holidays
# File path: /Users/runzhou/Desktop/rag/data/Lights For All The Holidays.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Lights For All The Holidays.mp4
# 0 captured frames.
# Object detection completed for 0 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Being Known as the Inflatable House in the Neighborhood is a Badge of Honor
# File path: /Users/runzhou/Desktop/rag/data/Being Known as the Inflatable House in the Neighborhood is a Badge of Honor.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Being Known as the Inflatable House in the Neighborhood is a Badge of Honor.mp4
# 0 captured frames.
# Object detection completed for 0 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How to Install Vinyl Plank Flooring | How To Anything
# File path: /Users/runzhou/Desktop/rag/data/How to Install Vinyl Plank Flooring  How To Anything.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Install Vinyl Plank Flooring  How To Anything.mp4
# 5 captured frames.
# Object detection completed for 5 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: If There's One Fridge That Can Handle Your Pre-Holiday Grocery Haul, This Is It!
# File path: /Users/runzhou/Desktop/rag/data/If Theres One Fridge That Can Handle Your Pre-Holiday Grocery Haul This Is It!.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/If Theres One Fridge That Can Handle Your Pre-Holiday Grocery Haul This Is It!.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Upgrade Your Door with a Smart Lock
# File path: /Users/runzhou/Desktop/rag/data/Upgrade Your Door with a Smart Lock.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Upgrade Your Door with a Smart Lock.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Want it, need it, gotta have it.
# File path: /Users/runzhou/Desktop/rag/data/Want it need it gotta have it.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Want it need it gotta have it.mp4
# 0 captured frames.
# Object detection completed for 0 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Update Your Ceiling with Faux Ceiling Beams
# File path: /Users/runzhou/Desktop/rag/data/Update Your Ceiling with Faux Ceiling Beams.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Update Your Ceiling with Faux Ceiling Beams.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How to Choose and Install Insulation | How To Anything
# File path: /Users/runzhou/Desktop/rag/data/How to Choose and Install Insulation  How To Anything.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Choose and Install Insulation  How To Anything.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Are you team decorate before or after Turkey Day?
# File path: /Users/runzhou/Desktop/rag/data/Are you team decorate before or after Turkey Day.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Are you team decorate before or after Turkey Day.mp4
# 2 captured frames.
# Object detection completed for 2 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How to Clean Your Kitchen Appliances
# File path: /Users/runzhou/Desktop/rag/data/How to Clean Your Kitchen Appliances.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Clean Your Kitchen Appliances.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How to Build and Install Faux Ceiling Beams | How To Anything
# File path: /Users/runzhou/Desktop/rag/data/How to Build and Install Faux Ceiling Beams  How To Anything.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Build and Install Faux Ceiling Beams  How To Anything.mp4
# 3 captured frames.
# Object detection completed for 3 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How to Deep Clean Kitchen Appliances | How To Anything
# File path: /Users/runzhou/Desktop/rag/data/How to Deep Clean Kitchen Appliances  How To Anything.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Deep Clean Kitchen Appliances  How To Anything.mp4
# 5 captured frames.
# Object detection completed for 5 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How To Use Tile Creatively
# File path: /Users/runzhou/Desktop/rag/data/How To Use Tile Creatively.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How To Use Tile Creatively.mp4
# 2 captured frames.
# Object detection completed for 2 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: As easy as 1,2,3! 🎄
# File path: /Users/runzhou/Desktop/rag/data/As easy as 123! 🎄.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/As easy as 123! 🎄.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: You can turn A👏N👏Y👏 door into a barn door with this kit!
# File path: /Users/runzhou/Desktop/rag/data/You can turn A👏N👏Y👏 door into a barn door with this kit!.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/You can turn A👏N👏Y👏 door into a barn door with this kit!.mp4
# 0 captured frames.
# Object detection completed for 0 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: Test Your Car Battery With a Multimeter
# File path: /Users/runzhou/Desktop/rag/data/Test Your Car Battery With a Multimeter.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Test Your Car Battery With a Multimeter.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How To DIY a Floating Vanity
# File path: /Users/runzhou/Desktop/rag/data/How To DIY a Floating Vanity.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How
mp4
# Processing file: /Users/runzhou/Desktop/rag/data/Lawn Mower Blades 101.mp4
# 0 captured frames.
# Object detection completed for 0 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: How to Sharpen, Balance and Change Lawn Mower Blades | How To Anything
# File path: /Users/runzhou/Desktop/rag/data/How to Sharpen Balance and Change Lawn Mower Blades  How To Anything.mp4
# Processing file: /Users/runzhou/Desktop/rag/data/How to Sharpen Balance and Change Lawn Mower Blades  How To Anything.mp4
# 1 captured frames.
# Object detection completed for 1 frames.
# Cleared directory: /Users/runzhou/Desktop/rag/data/video_frame_starttime
# Downloaded: The Weekender: "The Tropical Resort Style Patio" (Season 6, Episode 1)
# File path: /Users/runzhou/Desktop/rag/data/The Weekender The Tropical Resort Style Patio (Season 6 Episode 1).mp4
# Processing file: /Users/runzhou/Desktop/rag/data/The Weekender The Tropical Resort Style Patio (Season 6 Episode 1).mp4
# Error: Failed to read frame at 1447.819 seconds.
# 4 captured frames.
# Object detection completed for 4 frames.
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(df)
# Out:
# 0

# %% [markdown]
# ## TODO: Get more information for the YouTube videos, using video_id or url and YouTube API maybe

# %% [markdown]
# ### Thumbnail

# %%
import requests

youtube_video_id = 'bsOH6-bWMuU'

for i in range(4):
    url = f"https://img.youtube.com/vi/{youtube_video_id}/{i}.jpg"
    response = requests.get(url)
    if response.status_code == 200:
        with open(f"image_{i}.jpg", "wb") as f:
            f.write(response.content)
        print(f"Image {i} downloaded successfully.")
    else:
        print(f"Failed to download image {i}.")
# Out:
# Image 0 downloaded successfully.
# Image 1 downloaded successfully.
# Image 2 downloaded successfully.
# Image 3 downloaded successfully.

# %%
video_response = youtube.videos().list(
    part='snippet',
    id=youtube_video_id
).execute()

thumbnails = video_response['items'][0]['snippet']['thumbnails']

for thumbnail_type, thumbnail_info in thumbnails.items():
    print(f"Thumbnail type: {thumbnail_type}")
    print(f"Thumbnail URL: {thumbnail_info['url']}")
# Out:
# Thumbnail type: default
# Thumbnail URL: https://i.ytimg.com/vi/bsOH6-bWMuU/default.jpg
# Thumbnail type: medium
# Thumbnail URL: https://i.ytimg.com/vi/bsOH6-bWMuU/mqdefault.jpg
# Thumbnail type: high
# Thumbnail URL: https://i.ytimg.com/vi/bsOH6-bWMuU/hqdefault.jpg
# Thumbnail type: standard
# Thumbnail URL: https://i.ytimg.com/vi/bsOH6-bWMuU/sddefault.jpg
# Thumbnail type: maxres
# Thumbnail URL: https://i.ytimg.com/vi/bsOH6-bWMuU/maxresdefault.jpg

# %%
for i in ['default', 'mqdefault', 'hqdefault', 'sddefault', 'maxresdefault']:
    url = f"https://img.youtube.com/vi/{youtube_video_id}/{i}.jpg"
    response = requests.get(url)
    if response.status_code == 200:
        with open(f"image_{i}.jpg", "wb") as f:
            f.write(response.content)
        print(f"Image {i} downloaded successfully.")
    else:
        print(f"Failed to download image {i}.")
# Out:
# Image default downloaded successfully.
# Image mqdefault downloaded successfully.
# Image hqdefault downloaded successfully.
# Image sddefault downloaded successfully.
# Image maxresdefault downloaded successfully.

# %%
# Download the videos using pytube (FULL)
# %%
df.head(10)
# Out:
#                    labels                                   text_labels  \
# 0       [2, 76, 281, 446]             [Vehicle, Boat, Motorboat, Yacht]
# 1                   [191]                                       [Hotel]
# 2  [11, 1366, 1684, 1872]    [Food, Grocery store, Supermarket, Retail]
# 3        [2, 7, 116, 235]    [Vehicle, Car, Sport utility vehicle, nan]
# 4             [461, 1325]                    [Printer (computing), Ink]
# 5                   [607]                                  [Board game]
# 6       [0, 1, 234, 1303]  [Game, Video game, Super Smash Bros., Yoshi]
# 7                [17, 19]                          [Motorsport, Racing]
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=KYVAv4gq00k
# 1  https://www.youtube.com/watch?v=Ph-dQZnHChc
# 2  https://www.youtube.com/watch?v=jGve-X-fJug
# 3  https://www.youtube.com/watch?v=GnbzWaaIGRY
# 4          https://www.youtube.com/watch?v=200
# 5          https://www.youtube.com/watch?v=200
# 6  https://www.youtube.com/watch?v=DTQpR-AqKnM
# 7  https://www.youtube.com/watch?v=tTfptynuWdA
#
#                                      WikiDescription  \
# 0  [A vehicle is a mobile machine that transports...
# 1  [A hotel is an establishment that provides pai...
# 2  [Food is any substance consumed to provide nut...
# 3  [A vehicle is a mobile machine that transports...
# 4  [In computing, a printer is a peripheral which...
# 5  [A board game is a tabletop game that involves...
# 6  [A game is structured form of play, usually un...
# 7  [Motorsport or motorsports is a global term us...
#
#                                  text_segment_labels  \
# 0  [Luxury yacht, Luxury yacht, Luxury yacht, Lux...
# 1                              [Hotel, Hotel, Hotel]
# 2  [Grocery store, Grocery store, Grocery store, ...
# 3  [Sport utility vehicle, Sport utility vehicle,...
# 4                          [Ink, Ink, Ink, Ink, Ink]
# 5  [Board game, Board game, Board game, Board gam...
# 6                [Yoshi, Yoshi, Yoshi, Yoshi, Yoshi]
# 7      [Running, Running, Running, Running, Running]
#
#                                       segment_labels  \
# 0                     [1314, 1314, 1314, 1314, 1314]
# 1                                    [191, 191, 191]
# 2                     [1366, 1366, 1366, 1366, 1366]
# 3  [116, 116, 116, 235, 116, 235, 235, 116, 235, ...
# 4                     [1325, 1325, 1325, 1325, 1325]
# 5                          [607, 607, 607, 607, 607]
# 6                     [1303, 1303, 1303, 1303, 1303]
# 7                          [210, 210, 210, 210, 210]
#
#                                 segment_start_times  \
# 0                          [50, 165, 230, 115, 210]
# 1                                   [200, 255, 230]
# 2                           [85, 220, 230, 125, 45]
# 3  [265, 220, 65, 180, 105, 230, 105, 85, 135, 165]
# 4                             [50, 45, 85, 35, 110]
# 5                           [95, 215, 140, 60, 145]
# 6                          [185, 45, 190, 105, 195]
# 7                              [40, 65, 80, 30, 55]
#
#                                   segment_end_times  \
# 0                          [55, 170, 235, 120, 215]
# 1                                   [205, 260, 235]
# 2                           [90, 225, 235, 130, 50]
# 3  [270, 225, 70, 185, 110, 235, 110, 90, 140, 170]
# 4                             [55, 50, 90, 40, 115]
# 5                          [100, 220, 145, 65, 150]
# 6                          [190, 50, 195, 110, 200]
# 7                              [45, 70, 85, 35, 60]
#
#                                             mean_rgb  \
# 0  [0, 75, 148, 37, 0, 0, 74, 28, 194, 118, 230, ...
# 1  [89, 195, 86, 213, 96, 100, 151, 183, 103, 151...
# 2  [0, 72, 173, 30, 0, 0, 40, 33, 199, 132, 199, ...
# 3  [95, 203, 71, 171, 124, 165, 110, 172, 123, 17...
# 4  [86, 33, 92, 131, 206, 63, 92, 178, 43, 139, 5...
# 5  [116, 161, 174, 145, 99, 88, 64, 117, 147, 104...
# 6  [181, 16, 82, 162, 190, 255, 88, 28, 202, 213,...
# 7  [120, 193, 70, 224, 104, 170, 113, 125, 118, 1...
#
#                                           mean_audio
# 0  [175, 43, 116, 109, 154, 93, 75, 198, 172, 171...
# 1  [163, 55, 116, 98, 91, 183, 151, 157, 177, 117...
# 2  [175, 47, 132, 85, 169, 168, 156, 167, 157, 13...
# 3  [157, 37, 131, 92, 127, 93, 194, 217, 140, 103...
# 4  [133, 86, 84, 137, 155, 55, 95, 83, 153, 123, ...
# 5  [105, 70, 109, 126, 116, 29, 122, 114, 181, 18...
# 6  [156, 218, 194, 148, 121, 42, 8, 73, 68, 35, 9...
# 7  [65, 70, 167, 165, 166, 107, 173, 41, 113, 238...

# %%
from nnsplit import NNSplit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [96], line 1
# ----> 1 from nnsplit import NNSplit
#
# ModuleNotFoundError: No module named 'nnsplit'

# %%
transcript_data = video_info['bsOH6-bWMuU']

# get all transcript_text
transcript_texts = [item['transcript_text'] for item in transcript_data['video_transcript']]

# merge to one string
full_transcript = ' '.join(transcript_texts)
print(full_transcript)
#
# splitter = NNSplit.load("en")
#
# # returns `Split` objects
# splits = splitter.split(["This is a test This is another test"])[0]
#
# for idx, sentence in enumerate(splits):
#     print(f"Sentence {idx + 1}: {sentence}")
# Out:
# do you ever wonder how dirty your couch actually is I was shocked when I found out because all of that is so nasty thankfully I used this steam cleaner to get all of the areas that I realized were much dirtier than I expected I picked up the Bissell Little Green Pro heat that was super manageable and easy to use it even came with its own spot and stain remover solution to mix with hot water and spray on your stained area once I started cleaning I instantly saw results and was surprised by how quickly it worked I really like that the bristle brush really got the solution into those deeper Spains it was so s satisfying to see the steam cleaner work its magic and now I have a much cleaner couch because of it bye-bye dirty couch

# %%
# Out:
# labels                                                             [191]
# text_labels                                                      [Hotel]
# url                          https://www.youtube.com/watch?v=Ph-dQZnHChc
# WikiDescription        [A hotel is an establishment that provides pai...
# text_segment_labels                                [Hotel, Hotel, Hotel]
# segment_labels                                           [191, 191, 191]
# segment_start_times                                      [200, 255, 230]
# segment_end_times                                        [205, 260, 235]
# mean_rgb               [89, 195, 86, 213, 96, 100, 151, 183, 103, 151...
# mean_audio             [163, 55, 116, 98, 91, 183, 151, 157, 177, 117...
# Name: 1, dtype: object
